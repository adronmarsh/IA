# %%
import requests
page = requests.get("")

print (page.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="es">\n    <head>\n        <meta charset="utf-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1" />\n\n        <!-- CSRF Token -->\n        <meta name="csrf-token" content="Y29GijdGiAPpA5ZmE4vjel9o8qKQQvrQsfmwyhsb" />\n\n        <title>Asador de Pollos a la Le\xc3\xb1a - Asador La Morenica</title>\n        <meta\n            name="description"\n            content="\nDescubre nuestros productos y servicios. Asador de pollos, en horno de le\xc3\xb1a cerca de ti. \nComida para llevar, casera, innovadora y en Villena cerca de mi y de ti.\n"\n        />\n        <!-- Bootstrap -->\n        <link href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/css/bootstrap.min.css" rel="stylesheet" integrity="sha384-4bw+/aepP/YC94hEpVNVgiZdgIC5+VKNBQNGCHeKRQN+PtmoHDEXuppvnDJzQIu9" crossorigin="anonymous">\n        <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/js/bootstrap.bundle.min.js" integrity="sha384-HwwvtgBNo3bZJJ
# ...

# %%
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <!-- CSRF Token -->
# <meta content="Y29GijdGiAPpA5ZmE4vjel9o8qKQQvrQsfmwyhsb" name="csrf-token"/>
# <title>Asador de Pollos a la Leña - Asador La Morenica</title>
# <meta content="
# Descubre nuestros productos y servicios. Asador de pollos, en horno de leña cerca de ti.
# Comida para llevar, casera, innovadora y en Villena cerca de mi y de ti.
# " name="description"/>
# <!-- Bootstrap -->
# <link crossorigin="anonymous" href="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/css/bootstrap.min.css" integrity="sha384-4bw+/aepP/YC94hEpVNVgiZdgIC5+VKNBQNGCHeKRQN+PtmoHDEXuppvnDJzQIu9" rel="stylesheet"/>
# <script crossorigin="anonymous" integrity="sha384-HwwvtgBNo3bZJJLYd8oVXjrBZt8cqVSpeBNS5n7C8IVInixGAoxmnlMuBnhbgrkm" src="https://cdn.jsdelivr.net/npm/bootstrap@5.3.1/dist/js/bootstrap.bundle.min.js"></script>
# ...
