# %%
import requests
page = requests.get("https://www.temu.com/es/electronica-o3-248.html")

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(page.content)
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="es-ES"><head><script>
#         window.__PageContext__ = {"pagePath":"category"}
#       </script><script>
#             window.__CDN_IMG__ = {"retryLimit":3,"backupDomainConfigMap":{"img.kwcdn.com":{"img-1.kwcdn.com":50,"img-2.kwcdn.com":50},"aimg.kwcdn.com":{"aimg-1.kwcdn.com":50,"aimg-2.kwcdn.com":50}},"retryHostConfig":{"img.kwcdn.com":["img.kwcdn.com","img-1.kwcdn.com","img-2.kwcdn.com"],"aimg.kwcdn.com":["aimg.kwcdn.com","aimg-1.kwcdn.com","aimg-2.kwcdn.com"],"rewimg-us.kwcdn.com":["rewimg-us.kwcdn.com","rewimg-us-1.kwcdn.com","rewimg-us-2.kwcdn.com"],"rewimg-eu.kwcdn.com":["rewimg-eu.kwcdn.com","rewimg-eu-1.kwcdn.com","rewimg-eu-2.kwcdn.com"],"avatar-us.kwcdn.com":["avatar-us.kwcdn.com","avatar-us-1.kwcdn.com","avatar-us-2.kwcdn.com"],"avatar-eu.kwcdn.com":["avatar-eu.kwcdn.com","avatar-eu-1.kwcdn.com","avatar-eu-2.kwcdn.com"]},"sampleRate":0.01};
#             window.__PRIVACY_CONFIG__ = {"openRegions":[210,76,69,98,141,186,13,20,163,162,191,192,167,79,53,90,96,54,68,180,181,64,108,122,52,32,50,113,114,151],"cookies":{"region":1,"language":1,"currency":1,"timezone":1,"AccessToken":1,"isLogin":1,"user_uin":1,"_bee":1,"_nano_fp":1,"_order_token":1,"visitor_token":1,"isVisitor":1,"foterToken":1,"privacy_setting":1,"_u_pa":1,"address_snapshot_id":1,"dilx":1,"njrpl":1,"hfsc":1,"api_uid":1,"ETag":1,"install_token":1,"influencertoken":1,"webp":2,"_device_tag":{"type":2,"domain":".temu.com"},"account_history_list":2,"goods":2,"buildTag":2,"address_id":2,"shipping_city":3,"sc_cache_valid":3,"gtm_logger_session":3,"_ga":{"type":3,"domain":".temu.com"},"_ga_R8YHFZCMMX":{"type":3,"domain":".temu.com"},"_gcl_au":{"type":3,"domain":".temu.com"},"_fbp":{"type":3,"domain":".temu.com"},"id":{"type":3,"domain":".doubleclick.net"}},"cookiePromptAuthCloseTime":5000,"setStorageDelayTime":5000,"closeLeoConfig":{"salt":"bgcp22628","bucketCount":100,"defaultModel":"A","modelKeyArr":["A","B","C"],"models":{"A":{"whiteList":["CmyieWUNPmCDSAClZHKiAg=="],"blackList":[],"buckets":0},"B":{"whiteList":["CnCGqGUKmP5aPgBUA+K1Ag==","Cmw+AWUMV/O50QBRBBJnAg==","Cmw+AWUMPKS50QBRA/xDAg==","Cm0QZGURT0CQtABSBC0EAg=="],"blackList":[],"buckets":100},"C":{"whiteList":["Cm1Kq2RnIGKS4gBRaHmIAg==","Cm0C+WRjeppEDgBPBuuAAg==","CmzS0GURh4uvoABiL3LtAg==","Cm3GomQj2u+8CwFBgYDHAg=="],"blackList":[],"buckets":100}}},"delayImprTime":1500};
#             window.__CMT_AMPLIFY_RATE__ = 1;
#             window.__ERROR_SAMPLE_RATE__ = 1;
#           </script><script retain-in-offline="true">
#             "use strict";!function(){var r,e,n,o,a,i,c,u,t="__XRenderResourcesLoader__";function d(e){var r=document.createElement("a");return r.href=e,r.host}function l(e,r){if(r)for(var t in r)e[t]=r[t]}function s(e,r,t){return l(e,r),t&&l(e,t),e}function h(){var o=[];return{add:function(e){o.push(e)},emit:function(e){for(var r=o.slice(),t=0,n=r.length;t<n;t++)r[t](e)},clear:function(){o=[]}}}function f(t,n){!function e(){var r=document.querySelector('link[href="'.concat(t,'"]'));r?n(r):setTimeout(e)}()}function v(e){if(!e.sheet)return"loading";try{return 0<e.sheet.cssRules.length?"loaded":"errored"}catch(e){return"errored"}}function m(e,r,t){var n=new Error(r);n.errorCode=e,n.payload=s({message:r},t),n.type=501,setTimeout(function(){throw n},0)}function g(e){return/^(\d+(\.|$)){4}/.test(e)}function E(){var e,r,t;return i||(e=(null==(e=window.__CDN_IMG__)?void 0:e.retryHostConfig)||c,n||o||(r=e,t={},Object.keys(r).forEach(function(e){t[e]=r[e].filter(function(e){return!g(e)})}),e=t),i=e)}function p(e,r,t){var n=d(e),o=r.findIndex(function(e){return e===n}),o=r[(o+1)%r.length];return o?(r=e,e=o,o=t,(t=document.createElement("a")).href=r,g(t.host=e)?(t.protocol="http",t.search?t.search+="&host="+encodeURIComponent(o):t.search="host="+encodeURIComponent(o)):t.protocol="https",t.href):""}function y(e){return e.complete?e.naturalHeight<=1&&e.naturalWidth<=1?"errored":"loaded":"loading"}function T(e,r){return crypto.subtle.digest(function(e){switch(e){case"sha256":return"SHA-256";case"sha384":return"SHA-384";case"sha512":return"SHA-512";default:return"SHA-384"}}(r),e)}function _(i,c,a){var t;c&&a&&"fetch"in window&&(t=a.split("-")[0],fetch(c).then(function(n){var o,e;200===n.status&&(e=n,(r?e.text().then(function(e){return(new TextEncoder).encode(e).buffer}):e.arrayBuffer()).then(function(e){return T(o=e,r=t).then(function(e){e=btoa(String.fromCharCode.apply(null,new Uint8Array(e)));return"".concat(r,"-").concat(e)});var r}).then(function(e){var t,r;e!==a&&(r=o,r=(new TextDecoder).decode(r),o=null,t={el_type:i,resource:c,el_integrity:a,fetch_integrity:e,res_length:r.length,start_frag:r.slice(0,120),end_frag:r.slice(-120)},n.headers.forEach(function(e,r){t["header_".concat(r)]=e}),m(70200,"integrity not match",t))}).catch(function(){}))}).catch(function(){}))}function L(e,r,t){var n,o,i;return 0===e.index?t(s({},e,{url:r.initialUrl}),r):(o=r.retryHosts.shift())?(n=r.initialUrl,o=o,(i=document.createElement("a")).href=n,i.host=o,t(s({},e,{url:i.href}),r)):"reachLimit"}function w(e,r){return L(e,r,k)}function k(e,r){var t,n=r.initialEl,r=r.integrity,o=e.index,i=e.url,c=e.emitErrorType,o=0===o&&n,a=o?n:(i=i,r=r,(t=document.createElement("link")).href=i,t.rel="stylesheet",r&&(t.integrity=r),t.crossOrigin="anonymous",t),u={options:e,el:a,state:"loading",timeoutOrErrored:!1,Timeout:h(),Error:h(),Load:h(),clear:function(){(function(e){e.removeEventListener("load",f),e.removeEventListener("error",s),clearTimeout(d)})(u.el),clearTimeout(d),u.Error.clear(),u.Load.clear(),clearTimeout(l)},cancel:function(){u.el!==n&&(u.el.href="",u.el.remove())}},d=0,l=0;function s(){clearTimeout(d),u.state="errored",u.Error.emit()}function f(){clearTimeout(d),u.state="loaded",u.Load.emit()}function m(e){e.addEventListener("load",f),e.addEventListener("error",s),d=setTimeout(function(){u.Timeout.emit()},5e3)}return l=o?setTimeout(function(){var e=a,r=v(e);switch(r){case"errored":s();break;case"loading":m(e);break;case"loaded":f();break;default:}},0):setTimeout(function(){var e;m(e=a),n?n.insertAdjacentElement("afterend",e):document.head.appendChild(e)},"error"===c?100:0),u}function x(e,r){return L(e,r,H)}function H(e,r){n=e.url,r=r.integrity,(t=document.createElement("script")).src=n,t.crossOrigin="anonymous",r&&(t.integrity=r);var t,n,o=t,i={options:e,el:o,state:"loading",timeoutOrErrored:!1,Timeout:h(),Error:h(),Load:h(),clear:function(){(function(e){e.removeEventListener("load",d),e.removeEventListener("error",u),clearTimeout(c)})(i.el),i.Timeout.clear(),i ...
#             window.__XRenderResourcesLoader__.setBackupHosts(["static-1.kwcdn.com","static-2.kwcdn.com"])
#         </script><script>document.documentElement.setAttribute('data-theme', 't3');</script><meta charset="utf-8"/><script retain-in-offline="true">!function(t){var e=t._plt=t._plt||[];e.push(["tm","ps",+new Date]),(t.requestAnimationFrame||t.webkitRequestAnimationFrame||t.setTimeout)(function(){e.push(["tm","fraf",+new Date])})}(window);!function(){if("PerformanceLongTaskTiming" in window){var g=window.__tti={e:[]};g.o=new PerformanceObserver(function(l){g.e=g.e.concat(l.getEntries())});g.o.observe({entryTypes:["longtask"]})}}();!function(){var e,t,n,i,r={passive:!0,capture:!0},a=new Date,o=function(){i=[],t=-1,e=null,f(addEventListener)},c=function(i,r){e||(e=r,t=i,n=new Date,f(removeEventListener),u())},u=function(){if(t>=0&&t<n-a){var r={entryType:"first-input",name:e.type,target:e.target,cancelable:e.cancelable,startTime:e.timeStamp,processingStart:e.timeStamp+t};i.forEach((function(e){e(r)})),i=[]}},s=function(e){if(e.cancelable){var t=(e.timeStamp>1e12?new Date:performance.now())-e.timeStamp;"pointerdown"==e.type?function(e,t){var n=function(){c(e,t),a()},i=function(){a()},a=function(){removeEventListener("pointerup",n,r),removeEventListener("pointercancel",i,r)};addEventListener("pointerup",n,r),addEventListener("pointercancel",i,r)}(t,e):c(t,e)}},f=function(e){["mousedown","keydown","touchstart","pointerdown"].forEach((function(t){return e(t,s,r)}))},p="hidden"===document.visibilityState?0:1/0;addEventListener("visibilitychange",(function e(t){"hidden"===document.visibilityState&&(p=t.timeStamp,removeEventListener("visibilitychange",e,!0))}),!0);o(),self.webVitals={firstInputPolyfill:function(e){i.push(e),u()},resetFirstInputPolyfill:o,get firstHiddenTime(){return p}}}();</script><meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,user-scalable=no,viewport-fit=cover" name="viewport"/><meta content="telephone=no" name="format-detection"/><title>Electrónica - Devoluciones Gratuitas En 90 Días - Temu Spain</title><meta content="Electrónica - Devoluciones Gratuitas En 90 Días - Temu Spain" name="title"/><meta content="Electrónica" name="keywords"/><meta content="No te pierdas grandes ofertas en las últimas Electrónica. Envío gratuito y devoluciones gratuitas. Compre en Temu y comience a ahorrar." name="description"/><link href="https://www.temu.com/es/electronica-o3-248.html" rel="canonical"/><link href="https://www.temu.com/electronics-o3-248.html" hreflang="x-default" rel="alternate"/><link href="https://www.temu.com/electronics-o3-248.html" hreflang="en-US" rel="alternate"/><link href="https://www.temu.com/electronics-o3-248.html" hreflang="en" rel="alternate"/><link href="https://www.temu.com/us-es/electronica-o3-248.html" hreflang="es-US" rel="alternate"/><link href="https://www.temu.com/ca/electronics-o3-248.html" hreflang="en-CA" rel="alternate"/><link href="https://www.temu.com/ca-fr/electronics-o3-248.html" hreflang="fr-CA" rel="alternate"/><link href="https://www.temu.com/au/electronics-o3-248.html" hreflang="en-AU" rel="alternate"/><link href="https://www.temu.com/nz/electronics-o3-248.html" hreflang="en-NZ" rel="alternate"/><link href="https://www.temu.com/mx/electronica-o3-248.html" hreflang="es-MX" rel="alternate"/><link href="https://www.temu.com/mx-en/electronics-o3-248.html" hreflang="en-MX" rel="alternate"/><link href="https://www.temu.com/jp/electronics-o3-248.html" hreflang="ja-JP" rel="alternate"/><link href="https://www.temu.com/jp/electronics-o3-248.html" hreflang="ja" rel="alternate"/><link href="https://www.temu.com/jp-en/electronics-o3-248.html" hreflang="en-JP" rel="alternate"/><link href="https://www.temu.com/kr/electronics-o3-248.html" hreflang="ko-KR" rel="alternate"/><link href="https://www.temu.com/kr/electronics-o3-248.html" hreflang="ko" rel="alternate"/><link href="https://www.temu.com/kr-en/electronics-o3-248.html" hreflang="en-KR" rel="alternate"/><link href="https://www.temu.com/uk/electronics-o3-248.html" hreflang="en-GB" rel="alternate"/><link href="https://www.tem ...
#       if (window.__XRenderResourcesLoader__) {
#         window.__XRenderResourcesLoader__.handleCSSsRetry(["https://static.kwcdn.com/m-assets/assets/css/biz_vendors-5511b307a90013855cf4.css","https://static.kwcdn.com/m-assets/assets/css/5904-dd75c26db4e079974d63.css","https://static.kwcdn.com/m-assets/assets/css/2623-e7559c572ad52b20bc24.css","https://static.kwcdn.com/m-assets/assets/css/category-7f03c528165e21c23227.css"]);
#       }
#       </script><link crossorigin="anonymous" href="https://static.kwcdn.com/m-assets/assets/css/biz_vendors-5511b307a90013855cf4.css" integrity="sha384-uNg+9F33vNnV54bzOBxhIRS4FqIzx9g7pbiUIpHgF+WcogaBXahXgWsBYVwqncdw" rel="stylesheet"/><link crossorigin="anonymous" href="https://static.kwcdn.com/m-assets/assets/css/5904-dd75c26db4e079974d63.css" integrity="sha384-aBwcUtW1t1CvLcfvaMdebjk30AxKoWh2JnuqsO6uG7P6zKrQp4qv0UZvgyliwD6g" rel="stylesheet"/><link crossorigin="anonymous" href="https://static.kwcdn.com/m-assets/assets/css/2623-e7559c572ad52b20bc24.css" integrity="sha384-jwaFcSWpaJm9pwTntCAAHUVxNrVQSMUpDF5np/qrIIepJ4WAPLR8n1cyWH50YCn5" rel="stylesheet"/><link crossorigin="anonymous" href="https://static.kwcdn.com/m-assets/assets/css/category-7f03c528165e21c23227.css" integrity="sha384-PRVpybdhkmUcLcUkHw337xu0KVISRVTcLAbf7MFqnFNpEY6brVsidMM6Ex4UvXiR" rel="stylesheet"/><script>var pinbridge=function(){function n(t){return n="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(n){return typeof n}:function(n){return n&&"function"==typeof Symbol&&n.constructor===Symbol&&n!==Symbol.prototype?"symbol":typeof n},n(t)}var t=function(){try{if(top.pinbridge)return top.pinbridge}catch(n){setTimeout((function(){throw n}))}var t=0,o={},e=function e(r){if("object"!==n(r))return r;var i={};for(var c in"[object Array]"===Object.prototype.toString.call(r)&&(i=[]),r)if(r.hasOwnProperty(c)){var a=r[c];if("function"==typeof a){var u=++t;o[u]={func:a},i[c]="__aimi_function_"+u}else"object"===n(a)&&null!==a?i[c]=e(a):i[c]=a}return i},r=function(n,t,o,e){var r;"function"!=typeof(null===(r=window._fastJsN)||void 0===r?void 0:r.callNative)?(o=encodeURIComponent(JSON.stringify(o)),function(n){var t,o;null!==(t=window.webkit)&&void 0!==t&&null!==(o=t.messageHandlers)&&void 0!==o&&o.hybridAPIMessageHandler?window.webkit.messageHandlers.hybridAPIMessageHandler.postMessage({url:n}):null!=(navigator.userAgent||navigator.vendor).match(/phh_android_version/i)&&alert(n)}("pinbridge:///request?t=".concat(n,"&m=").concat(t,"&p=").concat(o,"&c=").concat(e))):window._fastJsN.callNative(n,t,o?JSON.stringify(o):null,e)},i=function(n,t,e){e=e||{};var r=o[n];if(r){var i=r.func,c=r.onSuccess,a=r.onError;i?i(t,e):0===t?c&&c(e):a&&a(e,t)}};return window.pinbridge={check:function(n,t){var o=arguments.length>2&&void 0!==arguments[2]?arguments[2]:function(){},e=arguments.length>3?arguments[3]:void 0;n&&t?window.pinbridge.callNative("AMBridgeAPI","check",{module_name:n,method_name:t},(function(n){return o(n&&n.exist)}),(function(){return e?e():o(!1)})):o(!1)},callNative:function(n,i,c,a,u){c=c||{};var l=++t;return o[l]={onSuccess:a,onError:u},c=e(c),r(n,i,c,l)},callbackFromNative:i,callback:i,removeCallback:function(n){delete o[n]}},window.pinbridge}();return t}();</script><script>
# (function() {
# var userAgent = navigator.userAgent;
# if(/phh_android_version/i.test(userAgent) || /phh_ios_version/i.test(userAgent)) {
#     window.pinbridge && window.pinbridge.callNative('JSUIControl', 'hideLoading');
# }
# })();</script><script>(function() {
#           function insert(n, m) {
#             for (var e = document.createDocumentFragment(), t = 0; t < n.length; t++) {
#               var o = document.createElement("script");
#               o.src = n[t];
#               o.crossOrigin = "anonymous";
#               if (m[t]) {
#                 o.integrity = m[t];
#               }
#               o.async = !1;
#               e.appendChild(o);
#             }
#             document.body.appendChild(e);
#           }
#           function loadScript(n, m) {
#             if (window.__XRenderResourcesLoader__) {
#               window.__XRenderResourcesLoader__.loadScripts(n, m);
#             } else {
#               insert(n, m);
#             }
#           }
#           function scriptDelayLoad(n, m) {
#             (window.requestAnimationFrame || window.webkitRequestAnimationFrame || setTimeout)(function() {
#                 loadScript(n, m)
#             })
#           }
#           var started;
#           function start() {
#             if (started) {
#               return;
#             }
#             started = true;
#             loadScript(
#             ["https://static.kwcdn.com/m-assets/assets/js/react_webpack_runtime_090b99cc7c3a35677ff8.js","https://static.kwcdn.com/m-assets/assets/js/biz_vendors_d24c705dc44e4919dcc6.js","https://static.kwcdn.com/m-assets/assets/js/vendors_066c84bfb97ba6fa3978.js","https://static.kwcdn.com/m-assets/assets/js/5904_360be10ced1a036c901b.js","https://static.kwcdn.com/m-assets/assets/js/2623_8f3d9b79cc9781501189.js","https://static.kwcdn.com/m-assets/assets/js/37_20acbae6e5ba4f38d0f3.js","https://static.kwcdn.com/m-assets/assets/js/2754_40bc36467863bf0668a3.js","https://static.kwcdn.com/m-assets/assets/js/category_65e10d92cdca85b25930.js"],
#             ["sha384-JXqjfzm4pKjAO6MwOfBn0v1QlxF87ulr0/dD0aPaOItSx9GChz7R8SfGK4uqwJbX","sha384-ZH9sH+rOelyH/eerHXSqOq7PthsgYJNaQCHb4Od/LXwQ9FWhyHwez5VxC1R5pWYj","sha384-1aRXoyjRTKX81jPwWaQroFan0qVNLVcXEtzmH6KfSoEnmQTya8nSkv7PXkqzivfA","sha384-iszwW4PwFpTULsj2/vnFzprYmV3agdCnj90IkAP6LrwVtcJYecLoUFQwKFcV3a79","sha384-/eoDJj2tjkQ/Uaqqmd93aaogmkn9rrWMXUh391cTKrgld9y10ByyjgIGm1Jl4TN3","sha384-ArEnPf2VTiKHAezTOvn3jlh1+CgXLH5nYWhtjGQWuaXBjJIr09gfFpqDZD45hW7K","sha384-L3KXav154oy1clRIy94GETqcV16zSPqc/v5bi6aGRHAhMpW7S0+bZs2h1Yxh7QIy","sha384-QIFZpMios2WNqMcjjOazT3WH0/67aNDlGS2Nxlw87s1WzgudvRYRy9Fpiv0FT1XZ"]
#             );
#           }
#
#           document.addEventListener('DOMContentLoaded', start);
#           setTimeout(function() {
#             if (window.hasOwnProperty('rawData')) {
#               start();
#             } else {
#               document.addEventListener("XRenderInitialPropsLoaded", start);
#             }
#           }, 3000);
#       }());</script><script>window.leoConfig={"__isCsr":false,"switches":{"enableEruda":false,"openShareWake":true,"openSort":true,"hideChat":1,"cssInline":true,"footerNofollow":true,"needLinkReferParams":true,"openSeoRecAllOpt":true,"seoRecOptList":[736,1562,1784,592,732,1224,1544,1134,1921,1514,1416,2045,1543,2652,6822,1366,1192,1504,1747,1916,1123,1431,2206,3007,1897,1481,1473,741,1685,533,845,743,2970,1919,740,1638,1900,1258,1849,1558,6809,2069,1540,30,1920,1490,2860,1580,2180,1769,1660,28,1553,1422,893],"linkParams":["rps","rpes","r_pid"]},"__CDN_IMG__":{"retryLimit":3,"backupDomainConfigMap":{"img.kwcdn.com":{"img-1.kwcdn.com":50,"img-2.kwcdn.com":50},"aimg.kwcdn.com":{"aimg-1.kwcdn.com":50,"aimg-2.kwcdn.com":50}},"retryHostConfig":{"img.kwcdn.com":["img.kwcdn.com","img-1.kwcdn.com","img-2.kwcdn.com"],"aimg.kwcdn.com":["aimg.kwcdn.com","aimg-1.kwcdn.com","aimg-2.kwcdn.com"],"rewimg-us.kwcdn.com":["rewimg-us.kwcdn.com","rewimg-us-1.kwcdn.com","rewimg-us-2.kwcdn.com"],"rewimg-eu.kwcdn.com":["rewimg-eu.kwcdn.com","rewimg-eu-1.kwcdn.com","rewimg-eu-2.kwcdn.com"],"avatar-us.kwcdn.com":["avatar-us.kwcdn.com","avatar-us-1.kwcdn.com","avatar-us-2.kwcdn.com"],"avatar-eu.kwcdn.com":["avatar-eu.kwcdn.com","avatar-eu-1.kwcdn.com","avatar-eu-2.kwcdn.com"]},"sampleRate":0.01},"__CMT_AMPLIFY_RATE__":1,"__ERROR_SAMPLE_RATE__":1,"node_response_error":{"openTest":false,"testUin":[],"testApiUid":[]},"fallbackStatic":false,"privacyConfig":{"openRegions":[210,76,69,98,141,186,13,20,163,162,191,192,167,79,53,90,96,54,68,180,181,64,108,122,52,32,50,113,114,151],"cookies":{"region":1,"language":1,"currency":1,"timezone":1,"AccessToken":1,"isLogin":1,"user_uin":1,"_bee":1,"_nano_fp":1,"_order_token":1,"visitor_token":1,"isVisitor":1,"foterToken":1,"privacy_setting":1,"_u_pa":1,"address_snapshot_id":1,"dilx":1,"njrpl":1,"hfsc":1,"api_uid":1,"ETag":1,"install_token":1,"influencertoken":1,"webp":2,"_device_tag":{"type":2,"domain":".temu.com"},"account_history_list":2,"goods":2,"buildTag":2,"address_id":2,"shipping_city":3,"sc_cache_valid":3,"gtm_logger_session":3,"_ga":{"type":3,"domain":".temu.com"},"_ga_R8YHFZCMMX":{"type":3,"domain":".temu.com"},"_gcl_au":{"type":3,"domain":".temu.com"},"_fbp":{"type":3,"domain":".temu.com"},"id":{"type":3,"domain":".doubleclick.net"}},"cookiePromptAuthCloseTime":5000,"setStorageDelayTime":5000,"closeLeoConfig":{"salt":"bgcp22628","bucketCount":100,"defaultModel":"A","modelKeyArr":["A","B","C"],"models":{"A":{"whiteList":["CmyieWUNPmCDSAClZHKiAg=="],"blackList":[],"buckets":0},"B":{"whiteList":["CnCGqGUKmP5aPgBUA+K1Ag==","Cmw+AWUMV/O50QBRBBJnAg==","Cmw+AWUMPKS50QBRA/xDAg==","Cm0QZGURT0CQtABSBC0EAg=="],"blackList":[],"buckets":100},"C":{"whiteList":["Cm1Kq2RnIGKS4gBRaHmIAg==","Cm0C+WRjeppEDgBPBuuAAg==","CmzS0GURh4uvoABiL3LtAg==","Cm3GomQj2u+8CwFBgYDHAg=="],"blackList":[],"buckets":100}}},"delayImprTime":1500},"searchBehaviorConfig":{"lastClickGoodsId":5,"lastCartGoodsId":1,"lastQuerys":3},"isCurrentPagePreloadScript":false,"performaceMark":"..."};
#     (function (w) {
#     w.__FALLBACK_STATIC__=w.leoConfig && w.leoConfig.fallbackStatic;
#     w.__CMT_AMPLIFY_RATE__=w.leoConfig && w.leoConfig.__CMT_AMPLIFY_RATE__;
#     w.__ERROR_SAMPLE_RATE__=w.leoConfig && w.leoConfig.__ERROR_SAMPLE_RATE__;
#     w.__CDN_IMG__=w.leoConfig && w.leoConfig.__CDN_IMG__ || {};
#     w.__PRIVACY_CONFIG__=w.leoConfig && w.leoConfig.privacyConfig || {};
#     })(window);</script><script>var initInlineLogger=function(){function e(e,r){var n=Object.keys(e);if(Object.getOwnPropertySymbols){var t=Object.getOwnPropertySymbols(e);r&&(t=t.filter((function(r){return Object.getOwnPropertyDescriptor(e,r).enumerable}))),n.push.apply(n,t)}return n}function r(r){for(var n=1;n<arguments.length;n++){var o=null!=arguments[n]?arguments[n]:{};n%2?e(Object(o),!0).forEach((function(e){t(r,e,o[e])})):Object.getOwnPropertyDescriptors?Object.defineProperties(r,Object.getOwnPropertyDescriptors(o)):e(Object(o)).forEach((function(e){Object.defineProperty(r,e,Object.getOwnPropertyDescriptor(o,e))}))}return r}function n(e){return n="function"==typeof Symbol&&"symbol"==typeof Symbol.iterator?function(e){return typeof e}:function(e){return e&&"function"==typeof Symbol&&e.constructor===Symbol&&e!==Symbol.prototype?"symbol":typeof e},n(e)}function t(e,r,n){return(r=function(e){var r=function(e,r){if("object"!=typeof e||null===e)return e;var n=e[Symbol.toPrimitive];if(void 0!==n){var t=n.call(e,r||"default");if("object"!=typeof t)return t;throw new TypeError("@@toPrimitive must return a primitive value.")}return("string"===r?String:Number)(e)}(e,"string");return"symbol"==typeof r?r:String(r)}(r))in e?Object.defineProperty(e,r,{value:n,enumerable:!0,configurable:!0,writable:!0}):e[r]=n,e}function o(e,r){if(null==e)return{};var n,t,o=function(e,r){if(null==e)return{};var n,t,o={},i=Object.keys(e);for(t=0;t<i.length;t++)n=i[t],r.indexOf(n)>=0||(o[n]=e[n]);return o}(e,r);if(Object.getOwnPropertySymbols){var i=Object.getOwnPropertySymbols(e);for(t=0;t<i.length;t++)n=i[t],r.indexOf(n)>=0||Object.prototype.propertyIsEnumerable.call(e,n)&&(o[n]=e[n])}return o}function i(e){return e.replace(/(%[0-9A-Z]{2})+/g,decodeURIComponent)}function a(e){var r=document.cookie?document.cookie.split("; "):[],n={};return r.some((function(r){var t=r.split("="),o=t.slice(1).join("="),a=i(t[0]);return o=i(o),n[a]=o,e===a})),e?n[e]||"":n}String.prototype.includes||(String.prototype.includes=function(e,r){return"number"!=typeof r&&(r=0),!(r+e.length>this.length)&&-1!==this.indexOf(e,r)});var u=function(){for(var e,r=[],n=0;n<256;n++){e=n;for(var t=0;t<8;t++)e=1&e?3988292384^e>>>1:e>>>1;r[n]=e}return r}();function s(e){var r=arguments.length>1&&void 0!==arguments[1]?arguments[1]:0;e=function(e){for(var r="",n=0;n<e.length;n++){var t=e.charCodeAt(n);t<128?r+=String.fromCharCode(t):t<2048?r+=String.fromCharCode(192|t>>6)+String.fromCharCode(128|63&t):t<55296||t>=57344?r+=String.fromCharCode(224|t>>12)+String.fromCharCode(128|t>>6&63)+String.fromCharCode(128|63&t):(t=65536+((1023&t)<<10|1023&e.charCodeAt(++n)),r+=String.fromCharCode(240|t>>18)+String.fromCharCode(128|t>>12&63)+String.fromCharCode(128|t>>6&63)+String.fromCharCode(128|63&t))}return r}(e),r^=-1;for(var n=0;n<e.length;n++)r=r>>>8^u[255&(r^e.charCodeAt(n))];return(-1^r)>>>0}var d={unknown:0,wifi:1,"slow-2g":2,"2g":2,"3g":3,"4g":4},c=d.unknown;function l(){var e="object"===("undefined"==typeof navigator?"undefined":n(navigator))&&navigator.connection&&("wifi"===navigator.connection.type?navigator.connection.type:navigator.connection.effectiveType);return d[e]||c}var p={Ios:/iphone|ipad|ipod/i,IosVersion:/os (\d+)_(\d+)_?(\d+)?/i,Android:/Android/i,AndroidVersion:/Android (\d+).?(\d+)?.?(\d+)?/i,AndroidNative:/phh_android_version/i,IosNative:/phh_ios_version/i,IosApiRequest:/BundleID\/com.einnovation.temu/i,Mobile:/Android|webOS|iPhone|iPad|iPod/i,AndroidNativeVersion:/(phh_android_version)\/([^\s]+)\s*/i,IosNativeVersion:/(phh_ios_version|AppVersion)\/([^\s]+)\s*/i,MecoWebViewCore:/MecoCore\/(\d)/i,MecoWebViewSdk:/MecoSDK\/(\d)/i,Crawler:/\+http|Chrome-Lighthouse|Google-InspectionTool/},g={Messenger:/\bFB[\w_]+\/(Messenger|MESSENGER)/,Facebook:/\bFB[\w_]+\//,Twitter:/\bTwitter/i,Line:/\bLine\//i,Instagram:/\bInstagram/i,Whatsapp:/\bWhatsApp/i,Snapchat:/Snapchat/i,Tiktok:/musical_ly/i,Pinterest:/Pinterest/i},f=/\bMozilla/i,v={Unknown:"unknown",Browser:"browser",NativeIOS:"ios",Nativ ...
#         window.__InitialI18nStore__={"es-ES":{"bec-fe.cookie-prompt":{"cookiePreference":{"wd_title":"Preferencia de cookies","rich_text":[{"text":"Utilizamos cookies y tecnologías similares para ofrecerte una mejor experiencia. Por lo general, la información no te identifica directamente, pero puede ofrecerte una experiencia más personalizada en la Web. Puedes cambiar la configuración de las cookies para aceptar o rechazar ciertas cookies y tecnologías similares a continuación. Recuerda, puedes personalizar la configuración de las cookies en cualquier momento en tu configuración de privacidad, en la que puedes acceder a nuestra"},{"text":"Política de privacidad y cookies","url":"/bgp_private_policy.html?title=Privacy%20%26%20Cookie%20Policy&_bg_fs=0"},{"text":"."}],"rich_text_v2":"Utilizamos cookies y tecnologías similares para brindarle una mejor experiencia. La información no suele identificarlo directamente, pero puede darte una experiencia web más personalizada. Puede cambiar su configuración de cookies para aceptar o rechazar ciertas cookies y tecnologías similares a continuación. Recuerda, puede personalizar su configuración de cookies en cualquier momento en su configuración de privacidad, donde puede acceder a nuestra <a>Política de privacidad y cookies</a>.","necessary_cookie":{"title":"Cookies estrictamente necesarias","rich_text":"Mantener activado","content_text":"Estas cookies son estrictamente necesarias para que nuestro sitio funcione de manera correcta y proporcionarte nuestros servicios y funciones. Estas cookies también nos permiten medir y analizar la forma en que nuestros clientes utilizan el sitio, para mejorar tanto su funcionalidad como tu experiencia de compra."},"preference_cookie":{"title":"Cookies de preferencia","option":0,"content_text":"Estas cookies recordarán tus preferencias (por ejemplo, tu idioma o ubicación) para que podamos hacer que tu experiencia de compra sea lo más fluida posible y personalizada para ti. Sin estas cookies, es posible que las cosas como las preferencias de tu cuenta o la localización no funcionen correctamente."},"analyse_cookie":{"title":"Cookies de marketing y análisis","option":0,"content_text":"Con tu consentimiento, utilizamos cookies y tecnologías similares para promover nuestros servicios en otras plataformas y sitios web, y para medir la eficacia de nuestras propias campañas de marketing. Nuestros socios de publicidad pueden recopilar tus datos personales para crear un perfil de tus intereses y mostrarte anuncios relevantes en otros sitios. Si no permites estas cookies, recibirás menos publicidad dirigida."},"accept_button_text":"Aceptar todo","confirm_button_text":"Confirmar mi elección","Title":"Añadido a la cesta","ViewCart":"Ver cesta","Cart":"Cesta"},"cookiePolicy":{"wd_title":"Política de privacidad y cookies","expire_time":5,"rich_text":[{"text":"Para ofrecerte la mejor experiencia, utilizamos cookies y tecnologías similares que son esenciales para proporcionarte nuestros servicios y funciones, y para fines de rendimiento, análisis y marketing. Haz clic en “Aceptar todo” o “Rechazar todo” si deseas permitir o rechazar todas las cookies para fines de rendimiento, análisis y marketing. De manera alternativa, puedes elegir qué tipos de cookies deseas aceptar o desactivar haciendo clic en “Personalizar cookies” a continuación, o en cualquier momento en tu configuración de privacidad. Para obtener más detalles, consulta nuestra "},{"text":"Política de privacidad y cookies","url":"/bgp_private_policy.html?title=Privacy%20%26%20Cookie%20Policy&_bg_fs=0"},{"text":"."}],"rich_text_v2":"Para ofrecerle la mejor experiencia, utilizamos cookies y tecnologías similares que son esenciales para proporcionarle nuestros servicios y funciones, con fines de rendimiento, análisis y marketing. Haz clic en “Aceptar todo” o “Rechazar todo” si deseas permitir o rechazar todas las cookies con fines de rendimiento, análisis y marketing. De manera alternativa, puede elegir qué tipos ...
#         window.__SumerCdnInfo__=undefined;
#         window.__InitialI18nStoreLoaded__=true;document.dispatchEvent(new Event('__InitialI18nStoreLoaded__'));</script><script>window.__DOC_SOURCE__="node"</script><script>!function(){String.prototype.includes||(String.prototype.includes=function(e,t){return"number"!=typeof t&&(t=0),!(t+e.length>this.length)&&-1!==this.indexOf(e,t)});var e=/phh_ios_version/i.test(navigator.userAgent),t=/phh_android_version/i.test(navigator.userAgent)||e;function o(e,t){if(!t)return e;for(var o in t)e[o]=t[o];return e}function n(e,t){var n,i,r=arguments.length>2&&void 0!==arguments[2]?arguments[2]:null,a=new Error(t);a.errorCode=e,a.payload=(o(n={message:t},r),o(n,i),n),a.type=501,setTimeout((function(){throw a}),0)}!function(){var e="chunkTimeoutReload",o=+window.__CHUNK_RELOAD_TIMOUT__||5e3,i="__torl";try{if(t?location.href.indexOf(i)>0:sessionStorage.getItem(e))return n(70002,"chunkTimeoutReloaded"),void(!t&&sessionStorage.removeItem(e))}catch(e){}setTimeout((function(){if(!document.querySelector("#main")){if(!t)try{sessionStorage.setItem(e,1)}catch(e){}var o=location.search;o+=o?"&":"?",o+="__csr=1&"+i,function(e){function o(){location.replace(e)}t&&window.pinbridge?window.pinbridge.callNative("WebScene","reload",{url:e},(function(){}),o):o()}(location.protocol+"//"+location.host+location.pathname+o+location.hash)}}),o)}()}();</script></head><body><div aria-hidden="true" style="height: 0">​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​​</div><div id="main"></div><script>window.__MONITOR_INFOS__ = {"usePanel":false,"reqId":"clnzys6xx3d510xdb0bebe2w3","serverData":{"tags":{},"marks":{"nodeInit":1697888178213,"noLog^api_api/poppy/v1/opt#start~1":1697888178219,"noLog^api_api/v3/rubicon/benefit/query#start~2":1697888178219,"noLog^api_api/poppy/v1/opt_list#start~3":1697888178219,"noLog^api_api/poppy/v1/shade_words#start~4":1697888178219,"noLog^api_api/alexa/homepage/bottom_tab#start~5":1697888178219,"noLog^api_api/bg/bg-uranus-api/uranus_cart/user_cart_num#start~6":1697888178219,"noLog^api_api/firefly/exp-config#start~7":1697888178219,"noLog^api_api/passport/token/touch#start~8":1697888178219,"noLog^api_api/seo/get_site_link#start~9":1697888178219,"noLog^api_api/poppy/v1/opt#start~10":1697888178219,"noLog^api_api/firefly/exp-config#start~11":1697888178219,"noLog^api_api/seo/get_common_biz_data#start~12":1697888178219,"noLog^api_api/alexa/homepage/bottom_tab#end~5":1697888178234,"noLog^api_api/seo/get_site_link#end~9":1697888178235,"noLog^api_api/seo/get_common_biz_data#end~12":1697888178236,"noLog^api_api/firefly/exp-config#end~11":1697888178236,"noLog^api_api/firefly/exp-config#end~7":1697888178237,"noLog^api_api/v3/rubicon/benefit/query#end~2":1697888178239},"fields":{},"longFields":{}}};</script><script retain-in-offline="true">window;</script></body></html>>
