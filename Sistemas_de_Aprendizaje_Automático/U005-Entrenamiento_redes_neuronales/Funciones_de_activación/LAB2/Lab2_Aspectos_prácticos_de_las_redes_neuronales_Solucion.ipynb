# %% [markdown]
# # Segunda parte: Aspectos prácticos de las redes neuronales
#
# En esta segunda parte, vamos a continuar desarrollando el problema de Fashion MNIST, con el objetivo de entender los aspectos prácticos del entrenamiento de redes neuronales que hemos visto en el tema
#
# El código utilizado para contestar tiene que quedar claramente reflejado en el Notebook. Puedes crear nuevas cells si así lo deseas para estructurar tu código y sus salidas. A la hora de entregar el notebook, **asegúrate de que los resultados de ejecutar tu código han quedado guardados**.

# %%
# Puedes añadir todos los imports adicionales que necesites aquí
import keras
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, BatchNormalization

import tensorflow as tf

import matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# #### Obtención de los datos y pre-processing

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train = x_train / 255.0
x_test = x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ## Consideraciones iniciales

# %% [markdown]
# ### Train-validation-test split
#
# En todos los modelos que entrenemos, vamos a partir los datos de training (x_train) en dos sets: training y validación. De este modo, al final tendremos tres datasets distintos: training, validation, y test. Esta es una estrategia común en el aprendizaje automático, en la que los datos de test (o held-out [texto del enlace](https://)data) se
# "esconden" hasta el final. Los datos de validación se utilizan para estimar cómo de bien están funcionando nuestros modelos y para observar si estamos cayendo en overfitting. Esto nos permite cambiar hiperparámetros y probar distintas arquitecturas **sabiendo que no estamos utilizando información del test set para "optimizar" los resultados en éste** (si eligiéramos nuestro mejor modelo en base a los resultados de test, estaríamos "haciendo trampas", ya que se ha utilizado la información contenida en éste para elegir el modelo y las métricas reportadas serían optimistas).
#
# Para utilizar un split training-validation data durante el entrenamiento, podemos partir nosotros mismos los datos o dejar que Keras lo haga. Podéis ver cómo hacer estas particiones en la documentación de *fit*.
#
# **Requisito: En todos los entrenamientos de esta práctica, se requiere utilizar el 20% de los datos en x_train como  conjunto de datos de validación**

# %% [markdown]
# ### Un error común con modelos de Keras
#
# En esta práctica entrenaremos varios modelos para comparar resultados. Un error común en Keras es no instanciar un nuevo modelo cada vez que hacemos un nuevo entrenamiento. Al hacer
#
# *model = Sequential()*
#
# *model.add(lo que sea)  # Definición del modelo*
#
# *model.fit()*
#
# si queremos entrenar un nuevo modelo o el mismo modelo otra vez, es necesario volver a inicializar el modelo con model = Sequential(). Si olvidamos este paso y volvemos a hacer fit(), el modelo seguirá entrenando por donde se quedó en el último fit().

# %% [markdown]
# ### Análisis de resultados
#
# A la hora de escribir las respuestas y los análisis pedidos, es importante presentar las conclusiones de manera adecuada a partir de lo visto en nuestros experimentos. Los Jupyter Notebook son una herramienta imprescindible para *data scientists* e ingenieros de Machine Learning para presentar los resultados, incluyendo soporte para incluir gráficas y elementos visuales. Podéis explicar vuestras observaciones del modo que consideréis adecuado, si bien recomendamos la utilización de gráficas para evaluar los entrenamientos y comparar resultados.
#
# Como ayuda, las siguientes funciones pueden resultar interesantes a la hora de evaluar resultados. Todas ellas utilizan el objeto *history* que podéis obtener como salida del método *fit()* de Keras:
#
# history = model.fit(x_train, y_train, ...)
#
# Por supuesto, podéis modificarlas y utilizarlas como prefiráis para crear vuestros propios informes.

# %%
def plot_acc(history, title="Model Accuracy"):
    """Imprime una gráfica mostrando la accuracy por epoch obtenida en un entrenamiento"""
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title(title)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper left')
    plt.show()
    
def plot_loss(history, title="Model Loss"):
    """Imprime una gráfica mostrando la pérdida por epoch obtenida en un entrenamiento"""
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    plt.show()
    
def plot_compare_losses(history1, history2, name1="Red 1",
                        name2="Red 2", title="Graph title"):
    """Compara losses de dos entrenamientos con nombres name1 y name2"""
    plt.rcParams['figure.figsize'] = (10, 8)  
    plt.plot(history1.history['loss'], color="green")
    plt.plot(history1.history['val_loss'], 'r--', color="green")
    plt.plot(history2.history['loss'], color="blue")
    plt.plot(history2.history['val_loss'], 'r--', color="blue")
    plt.title(title)
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.legend(['Train ' + name1, 'Val ' + name1, 
                'Train ' + name2, 'Val ' + name2],
               loc='upper right')
    plt.show()
    
def plot_compare_accs(history1, history2, name1="Red 1",
                      name2="Red 2", title="Graph title"):
    """Compara accuracies de dos entrenamientos con nombres name1 y name2"""
    plt.rcParams['figure.figsize'] = (10, 8)  
    plt.plot(history1.history['accuracy'], color="green")
    plt.plot(history1.history['val_accuracy'], 'r--', color="green")
    plt.plot(history2.history['accuracy'], color="blue")
    plt.plot(history2.history['val_accuracy'], 'r--', color="blue")
    plt.title(title)
    plt.ylabel('Accuracy')
    plt.xlabel('Epoch')
    plt.legend(['Train ' + name1, 'Val ' + name1, 
                'Train ' + name2, 'Val ' + name2], 
               loc='lower right')
    plt.show()
    
# Nota: podéis cambiar los números aquí presentes y ejecutar esta línea si queréis cambiar el tamaño
# de las gráficas
# matplotlib.rcParams['figure.figsize'] = [8, 8]

# %% [markdown]
# ## 1. Unidades de activación

# %%
from keras.optimizers import RMSprop, SGD

epochs = 20 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 64 # cantidad de imágenes que se toman a la vez en memoria

# %% [markdown]
# En este ejercicio, vamos a evaluar la importancia de utilizar las unidades de activación adecuadas. Como hemos visto en clase, funciones de activación como sigmoid han dejado de utilizarse en favor de otras unidades como ReLU.
#
# **Ejercicio 1 ****: Partiendo de una red sencilla como la desarrollada en la actividad 1, escribir un breve análisis comparando la utilización de unidades sigmoid y ReLU (por ejemplo, se pueden comentar aspectos como velocidad de convergencia, métricas obtenidas...). Explicar por qué pueden darse estas diferencias. Opcionalmente, comparar con otras activaciones disponibles en Keras.

# %%
#Tenemos 10 clases que varian de 0 a 9 como hemos visto en los puntos anteriores.
num_clases=10

#Transformamos el formato de las imagenes de un vector bi-dimensional (de 28 por 28 pixeles) a un vector unidimensional (de 28*28 pixeles = 784 pixeles)
x_train_total = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

#Transformamos el vector de la variable y es categorico.
y_train_total = keras.utils.to_categorical(y_train, num_clases)
y_test = keras.utils.to_categorical(y_test, num_clases)

#Reservamos el 20 % que serian 12000 imagenes para validación.
x_val = x_train_total[-12000:]
y_val = y_train_total[-12000:]
x_train = x_train_total[:-12000]
y_train = y_train_total[:-12000]

# %% [markdown]
# ### Experimento 1 - Sigmoid vs Relu

# %%
model = Sequential()
model.add(Dense(128,activation='sigmoid', input_shape=(784,)))
model.add(Dense(64,activation='sigmoid'))
model.add(Dense(num_clases,activation='softmax'))

model.summary()


model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),            
              metrics=['accuracy'])


history_sigmoid = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               100480
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 5s 5ms/step - loss: 2.2072 - accuracy: 0.3730 - val_loss: 2.0799 - val_accuracy: 0.5587
# Epoch 2/20
# 750/750 [==============================] - 3s 4ms/step - loss: 1.9060 - accuracy: 0.5584 - val_loss: 1.7184 - val_accuracy: 0.5195
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 1.5649 - accuracy: 0.5880 - val_loss: 1.4235 - val_accuracy: 0.6174
# Epoch 4/20
# 750/750 [==============================] - 4s 6ms/step - loss: 1.3253 - accuracy: 0.6309 - val_loss: 1.2287 - val_accuracy: 0.6495
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 1.1640 - accuracy: 0.6583 - val_loss: 1.0939 - val_accuracy: 0.6589
# Epoch 6/20
# 750/750 [==============================] - 3s 4ms/step - loss: 1.0496 - accuracy: 0.6752 - val_loss: 0.9950 - val_accuracy: 0.6900
# Epoch 7/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.9650 - accuracy: 0.6939 - val_loss: 0.9218 - val_accuracy: 0.7036
# Epoch 8/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.8998 - accuracy: 0.7062 - val_loss: 0.8635 - val_accuracy: 0.7159
# Epoch 9/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.8484 - accuracy: 0.7166 - val_loss: 0.8175 - val_accuracy: 0.7246
# Epoch 10/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.8067 - accuracy: 0.7256 - val_loss: 0.7805 - val_accuracy: 0.7343
# Epoch 11/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.7724 - accuracy: 0.7333 - val_loss: 0.7502 - val_accuracy: 0.7402
# Epoch 12/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.7435 - accuracy: 0.7390 - val_loss: 0.7238 - val_accuracy: 0.7458
# Epoch 13/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.7190 - accuracy: 0.7428 - val_loss: 0.7025 - val_accuracy: 0.7512
# Epoch 14/20
# 750/750 [==============================] - 7s 9ms/step - loss: 0.6982 - accuracy: 0.7482 - val_loss: 0.6834 - val_accuracy: 0.7477
# Epoch 15/20
# 750/750 [==============================] - 6s 9ms/step - loss: 0.6803 - accuracy: 0.7519 - val_loss: 0.6667 - val_accuracy: 0.7565
# Epoch 16/20
# 750/750 [==============================] - 7s 10ms/step - loss: 0.6643 - accuracy: 0.7556 - val_loss: 0.6518 - val_accuracy: 0.7613
# Epoch 17/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.6503 - accuracy: 0.7594 - val_loss: 0.6393 - val_accuracy: 0.7627
# Epoch 18/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.6378 - accuracy: 0.7635 - val_loss: 0.6276 - val_accuracy: 0.7655
# Epoch 19/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.6264 - accuracy: 0.7668 - val_loss: 0.6172 - val_accuracy: 0.7662
# Epoch 20/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.6157 - accuracy: 0.7706 - val_loss: 0.6074 - val_accuracy: 0.7736

# %%
# Probando ReLU

model = Sequential()
model.add(Dense(128,activation='relu', input_shape=(784,)))
model.add(Dense(64,activation='relu'))
model.add(Dense(num_clases,activation='softmax'))

model.summary()


model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),            
              metrics=['accuracy'])


history_relu = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 128)               100480
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  dense_5 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 4s 5ms/step - loss: 1.0103 - accuracy: 0.6770 - val_loss: 0.6511 - val_accuracy: 0.7802
# Epoch 2/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.5911 - accuracy: 0.8008 - val_loss: 0.5501 - val_accuracy: 0.8062
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5192 - accuracy: 0.8216 - val_loss: 0.4937 - val_accuracy: 0.8282
# Epoch 4/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4826 - accuracy: 0.8331 - val_loss: 0.4735 - val_accuracy: 0.8367
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4605 - accuracy: 0.8407 - val_loss: 0.4534 - val_accuracy: 0.8410
# Epoch 6/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.4433 - accuracy: 0.8470 - val_loss: 0.4364 - val_accuracy: 0.8502
# Epoch 7/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4294 - accuracy: 0.8514 - val_loss: 0.4279 - val_accuracy: 0.8533
# Epoch 8/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4185 - accuracy: 0.8550 - val_loss: 0.4247 - val_accuracy: 0.8522
# Epoch 9/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4081 - accuracy: 0.8587 - val_loss: 0.4155 - val_accuracy: 0.8548
# Epoch 10/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3982 - accuracy: 0.8620 - val_loss: 0.4097 - val_accuracy: 0.8587
# Epoch 11/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3912 - accuracy: 0.8635 - val_loss: 0.3976 - val_accuracy: 0.8618
# Epoch 12/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3831 - accuracy: 0.8659 - val_loss: 0.4079 - val_accuracy: 0.8552
# Epoch 13/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3767 - accuracy: 0.8676 - val_loss: 0.3855 - val_accuracy: 0.8643
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3698 - accuracy: 0.8704 - val_loss: 0.3993 - val_accuracy: 0.8605
# Epoch 15/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3644 - accuracy: 0.8723 - val_loss: 0.3893 - val_accuracy: 0.8652
# Epoch 16/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3593 - accuracy: 0.8735 - val_loss: 0.3737 - val_accuracy: 0.8689
# Epoch 17/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3532 - accuracy: 0.8751 - val_loss: 0.3826 - val_accuracy: 0.8655
# Epoch 18/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3492 - accuracy: 0.8758 - val_loss: 0.3715 - val_accuracy: 0.8695
# Epoch 19/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3440 - accuracy: 0.8792 - val_loss: 0.3938 - val_accuracy: 0.8622
# Epoch 20/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3388 - accuracy: 0.8795 - val_loss: 0.3657 - val_accuracy: 0.8714

# %%
#Vamos a comparar el accuracy y las perdidas de cada modelo.
plot_compare_accs(history_sigmoid, history_relu, name1="history_sigmoid",name2="history_relu", title="Acurracy Sigmoid vs ReLU")
plot_compare_losses(history_sigmoid, history_relu, name1="history_sigmoid",name2="history_relu", title="Perdida Sigmoid vs ReLU")

# %% [markdown]
# #### Conclusión
# En ambos gráficos podemos ver lo bien que se comporta ReLU con respecto a Sigmoid. Esta última tiende a saturarse cuando sus valores tienden a 0 o a 1, pequeños cambios en x no implicación en y. Al estar saturada la derivada es prácticamente 0, entonces el gradiente resultante es aproximadamente es 0 con esto tenemos el efecto que eliminamos la señal de aprendizaje. Otro de los problemas que se puede apreciar en esta práctica es que la señal no esta centrada en 0, esto provoca que los valores siempre sean positivos, estas salidas positivas provocan que el fenómeno en las siguientes capas. Por último, también tienen problema con la complejidad de operaciones, pero este no lo hemos apreciado en esta práctica, ya que la red es muy pequeña. Ambas se han comportado entornos a 2s por época.
# Por otro lado ReLU no satura en régimen positivo ya que x>0, por otro lado al ser una función lineal y centrada en 0 tampoco tiene problemas en la aproximaciones a 0 o 1.

# %% [markdown]
# ### Experimento 2 - Relu vs Tangente Hiperbólica

# %%
# Probando tanh

model = Sequential()
model.add(Dense(128,activation='tanh', input_shape=(784,)))
model.add(Dense(64,activation='tanh'))
model.add(Dense(num_clases,activation='softmax'))

model.summary()


model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),            
              metrics=['accuracy'])


history_tanh = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 128)               100480
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  dense_8 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.8844 - accuracy: 0.7163 - val_loss: 0.6390 - val_accuracy: 0.7859
# Epoch 2/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.5815 - accuracy: 0.8039 - val_loss: 0.5434 - val_accuracy: 0.8112
# Epoch 3/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.5121 - accuracy: 0.8241 - val_loss: 0.4995 - val_accuracy: 0.8213
# Epoch 4/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4770 - accuracy: 0.8345 - val_loss: 0.4725 - val_accuracy: 0.8312
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4544 - accuracy: 0.8406 - val_loss: 0.4515 - val_accuracy: 0.8410
# Epoch 6/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4370 - accuracy: 0.8465 - val_loss: 0.4384 - val_accuracy: 0.8426
# Epoch 7/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4235 - accuracy: 0.8510 - val_loss: 0.4318 - val_accuracy: 0.8453
# Epoch 8/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4130 - accuracy: 0.8546 - val_loss: 0.4178 - val_accuracy: 0.8503
# Epoch 9/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4032 - accuracy: 0.8587 - val_loss: 0.4130 - val_accuracy: 0.8534
# Epoch 10/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3953 - accuracy: 0.8595 - val_loss: 0.4088 - val_accuracy: 0.8547
# Epoch 11/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3883 - accuracy: 0.8633 - val_loss: 0.4024 - val_accuracy: 0.8566
# Epoch 12/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3819 - accuracy: 0.8649 - val_loss: 0.3945 - val_accuracy: 0.8594
# Epoch 13/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3755 - accuracy: 0.8668 - val_loss: 0.3888 - val_accuracy: 0.8594
# Epoch 14/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3705 - accuracy: 0.8690 - val_loss: 0.3842 - val_accuracy: 0.8618
# Epoch 15/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3656 - accuracy: 0.8708 - val_loss: 0.3818 - val_accuracy: 0.8632
# Epoch 16/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3606 - accuracy: 0.8722 - val_loss: 0.3782 - val_accuracy: 0.8656
# Epoch 17/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3565 - accuracy: 0.8729 - val_loss: 0.3795 - val_accuracy: 0.8632
# Epoch 18/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3527 - accuracy: 0.8745 - val_loss: 0.3760 - val_accuracy: 0.8637
# Epoch 19/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3486 - accuracy: 0.8760 - val_loss: 0.3691 - val_accuracy: 0.8689
# Epoch 20/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3448 - accuracy: 0.8776 - val_loss: 0.3751 - val_accuracy: 0.8668

# %%
#Vamos a comparar los
plot_compare_accs(history_tanh, history_relu, name1="history_tanh",name2="history_relu", title="Perdida Tanh vs ReLU")
plot_compare_losses(history_tanh, history_relu, name1="history_tanh",name2="history_relu", title="Perdida Tanh vs ReLU")

# %% [markdown]
# #### Conclusión
# Ahora estamos comparando ReLU con tanh (Tangente hiperbólica). En ambas gráficas se puede observar que el rendimiento de ReLU es mejor, pero no con tanta diferencia como con Sigmoid. Tanh sigue teniendo el problema de que “mata” gradientes, pero por el contrario esta centrada en 0. Por lo que en este experimento se puede sacar la conclusión que hay mayor mejoria por que la señal de activación este centrada en 0, que por que la derivada local tienda a 0 en los extremos.

# %% [markdown]
# ## 2. Inicialización de parámetros

# %% [markdown]
# En este ejercicio, vamos a evaluar la importancia de una correcta inicialización de parámetros en una red neuronal.
#
# **Ejercicio 2 **: Partiendo de una red similar a la del ejercicio anterior (usando ya ReLUs), comentar las diferencias que se aprecian en el entrenamiento al utilizar distintas estrategias de inicialización de parámetros. Para ello, inicializar todas las capas con las siguientes estrategias, disponibles en Keras, y analizar sus diferencias:
#
# * Inicialización con ceros.
# * Inicialización con una variable aleatoria normal.
# * Inicialización con los valores por defecto de Keras para una capa Dense (estrategia *glorot uniform*)

# %% [markdown]
# ### Experimento 3 - Zero vs Glorot uniform vs Aleatoria Normal

# %%
def modelo_ejercicio2():

  print(activation)
  print(initialization)
  model = Sequential()
  model.add(Dense(128,kernel_initializer=initialization,activation=activation, input_shape=(784,)))
  model.add(Dense(64,kernel_initializer=initialization,activation=activation))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer=SGD(),            
              metrics=['accuracy'])


  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
activation='relu'
initialization='random_normal'
history_normal=modelo_ejercicio2()
initialization='zero'
history_zero=modelo_ejercicio2()
initialization='glorot_uniform'
history_glorot=modelo_ejercicio2()
# Out:
# relu
# random_normal
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_9 (Dense)             (None, 128)               100480
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  dense_11 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 4s 5ms/step - loss: 1.0965 - accuracy: 0.6658 - val_loss: 0.7077 - val_accuracy: 0.7592
# Epoch 2/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.6431 - accuracy: 0.7835 - val_loss: 0.5907 - val_accuracy: 0.7975
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5557 - accuracy: 0.8116 - val_loss: 0.5268 - val_accuracy: 0.8138
# Epoch 4/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5127 - accuracy: 0.8233 - val_loss: 0.5062 - val_accuracy: 0.8215
# Epoch 5/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.4865 - accuracy: 0.8303 - val_loss: 0.5086 - val_accuracy: 0.8133
# Epoch 6/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4659 - accuracy: 0.8378 - val_loss: 0.4758 - val_accuracy: 0.8303
# Epoch 7/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4511 - accuracy: 0.8426 - val_loss: 0.4849 - val_accuracy: 0.8235
# Epoch 8/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4396 - accuracy: 0.8456 - val_loss: 0.4384 - val_accuracy: 0.8468
# Epoch 9/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4289 - accuracy: 0.8512 - val_loss: 0.4566 - val_accuracy: 0.8356
# Epoch 10/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4191 - accuracy: 0.8531 - val_loss: 0.4276 - val_accuracy: 0.8497
# Epoch 11/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4109 - accuracy: 0.8557 - val_loss: 0.4233 - val_accuracy: 0.8516
# Epoch 12/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4035 - accuracy: 0.8595 - val_loss: 0.4172 - val_accuracy: 0.8551
# Epoch 13/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3962 - accuracy: 0.8602 - val_loss: 0.4234 - val_accuracy: 0.8521
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3890 - accuracy: 0.8643 - val_loss: 0.3978 - val_accuracy: 0.8597
# Epoch 15/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3837 - accuracy: 0.8655 - val_loss: 0.4016 - val_accuracy: 0.8567
# Epoch 16/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3775 - accuracy: 0.8672 - val_loss: 0.3935 - val_accuracy: 0.8622
# Epoch 17/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3720 - accuracy: 0.8704 - val_loss: 0.3869 - val_accuracy: 0.8637
# Epoch 18/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3668 - accuracy: 0.8708 - val_loss: 0.3918 - val_accuracy: 0.8623
# Epoch 19/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3619 - accuracy: 0.8720 - val_loss: 0.3804 - val_accuracy: 0.8662
# Epoch 20/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3573 - accuracy: 0.8740 - val_loss: 0.3778 - val_accuracy: 0.8688
# relu
# zero
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 128)               100480
#
#  dense_13 (Dense)            (None, 64)                8256
#
#  dense_14 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 4s 5ms/step - loss: 2.3026 - accuracy: 0.0968 - val_loss: 2.3026 - val_accuracy: 0.0957
# Epoch 2/20
# 750/750 [==============================] - 3s 5ms/step - loss: 2.3026 - accuracy: 0.0990 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 3/20
# 750/750 [==============================] - 8s 10ms/step - loss: 2.3026 - accuracy: 0.1012 - val_loss: 2.3027 - val_accuracy: 0.0983
# Epoch 4/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 5/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.0982 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 6/20
# 750/750 [==============================] - 4s 5ms/step - loss: 2.3026 - accuracy: 0.1002 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 7/20
# 750/750 [==============================] - 4s 5ms/step - loss: 2.3026 - accuracy: 0.0980 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 8/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.1001 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 9/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.0985 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 10/20
# 750/750 [==============================] - 4s 6ms/step - loss: 2.3026 - accuracy: 0.1004 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 11/20
# 750/750 [==============================] - 3s 5ms/step - loss: 2.3026 - accuracy: 0.1003 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 12/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.0999 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 13/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.0999 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 14/20
# 750/750 [==============================] - 4s 5ms/step - loss: 2.3026 - accuracy: 0.1009 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 15/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.1011 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 16/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.1005 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 17/20
# 750/750 [==============================] - 4s 5ms/step - loss: 2.3026 - accuracy: 0.0988 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 18/20
# 750/750 [==============================] - 4s 5ms/step - loss: 2.3026 - accuracy: 0.0993 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 19/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.1006 - val_loss: 2.3027 - val_accuracy: 0.0957
# Epoch 20/20
# 750/750 [==============================] - 3s 4ms/step - loss: 2.3026 - accuracy: 0.1000 - val_loss: 2.3027 - val_accuracy: 0.0957
# relu
# glorot_uniform
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_15 (Dense)            (None, 128)               100480
#
#  dense_16 (Dense)            (None, 64)                8256
#
#  dense_17 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.9696 - accuracy: 0.6969 - val_loss: 0.6339 - val_accuracy: 0.7824
# Epoch 2/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5813 - accuracy: 0.8033 - val_loss: 0.5410 - val_accuracy: 0.8091
# Epoch 3/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.5151 - accuracy: 0.8236 - val_loss: 0.4982 - val_accuracy: 0.8270
# Epoch 4/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4789 - accuracy: 0.8345 - val_loss: 0.4725 - val_accuracy: 0.8357
# Epoch 5/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4577 - accuracy: 0.8412 - val_loss: 0.4650 - val_accuracy: 0.8382
# Epoch 6/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4397 - accuracy: 0.8474 - val_loss: 0.4487 - val_accuracy: 0.8439
# Epoch 7/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.4265 - accuracy: 0.8512 - val_loss: 0.4315 - val_accuracy: 0.8491
# Epoch 8/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4167 - accuracy: 0.8545 - val_loss: 0.4261 - val_accuracy: 0.8488
# Epoch 9/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.4064 - accuracy: 0.8583 - val_loss: 0.4297 - val_accuracy: 0.8507
# Epoch 10/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3966 - accuracy: 0.8612 - val_loss: 0.4157 - val_accuracy: 0.8527
# Epoch 11/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3899 - accuracy: 0.8638 - val_loss: 0.4030 - val_accuracy: 0.8572
# Epoch 12/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3831 - accuracy: 0.8658 - val_loss: 0.4013 - val_accuracy: 0.8609
# Epoch 13/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3759 - accuracy: 0.8686 - val_loss: 0.3933 - val_accuracy: 0.8622
# Epoch 14/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3706 - accuracy: 0.8691 - val_loss: 0.3956 - val_accuracy: 0.8621
# Epoch 15/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3651 - accuracy: 0.8720 - val_loss: 0.3984 - val_accuracy: 0.8582
# Epoch 16/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3593 - accuracy: 0.8736 - val_loss: 0.3813 - val_accuracy: 0.8658
# Epoch 17/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3545 - accuracy: 0.8750 - val_loss: 0.3887 - val_accuracy: 0.8607
# Epoch 18/20
# 750/750 [==============================] - 3s 4ms/step - loss: 0.3498 - accuracy: 0.8762 - val_loss: 0.3779 - val_accuracy: 0.8665
# Epoch 19/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3445 - accuracy: 0.8782 - val_loss: 0.3729 - val_accuracy: 0.8704
# Epoch 20/20
# 750/750 [==============================] - 3s 5ms/step - loss: 0.3406 - accuracy: 0.8796 - val_loss: 0.3869 - val_accuracy: 0.8648

# %%
#Vamos a comparar el accuracy y las perdidas de cada modelo.
plot_compare_accs(history_zero, history_glorot, name1="history_zero",name2="history_glorot", title="Acurracy Zero vs Glorot")
plot_compare_losses(history_zero, history_glorot, name1="history_zero",name2="history_glorot", title="Perdida Zero vs Glorot")

# %% [markdown]
# #### Conclusión 3.1
# Podemos apreciar que la inicialización Glorot uniform es mucho mejor que la que con ceros. De hecho, en la inicialización por 0 la función de perdida no decrece, es la peor situación ya que nuestra red neuronal no esta aprendiendo. Ocurre esta situación por que todas los paramentros tienen el mismo valor, esto hace que tengan el mismo peso de entrada, por lo que el gradiente repecto a los pesos es el mismo, lo paramentos cambiaran siempre de la misma manera y nuestra red no aprendera nada.

# %%
plot_compare_accs(history_normal, history_glorot, name1="history_normal",name2="history_glorot", title="Acurracy Normal vs Glorot")
plot_compare_losses(history_normal, history_glorot, name1="history_normal",name2="history_glorot", title="Perdida Normal vs Glorot")

# %% [markdown]
# #### Conclusión *3.2*
#
# En este caso la inicialización por defecto Glorot uniform tiene mejor rendimiento que una inicialización aleatoria normal. Podemos ver que en ambos casos la función de perdida decrece, pero en las primeras epoch es cuando la inicialización por defecto se comporta mejor. Esto se debe a que Glorot tiende a que la varianza de salida de una neurona sea igual que la de entrada, esta situación hace que se acelere la convergencia al entrenar.

# %% [markdown]
# ## 3. Optimizadores

# %% [markdown]
# **Ejercicio 3 ****: Partiendo de una red similar a la del ejercicio anterior (utilizando la mejor estrategia de inicialización observada), comparar y analizar las diferencias que se observan  al entrenar con varios de los optimizadores vistos en clase, incluyendo SGD como optimizador básico (se puede explorar el espacio de hiperparámetros de cada optimizador, aunque para optimizadores más avanzados del estilo de adam y RMSprop es buena idea dejar los valores por defecto provistos por Keras).

# %% [markdown]
# Experimento 4 - Adam vs SGD

# %%
def modelo_ejercicio3(activation,optimizer):

  model = Sequential()
  model.add(Dense(128,activation=activation, input_shape=(784,)))
  model.add(Dense(64,activation=activation))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer=optimizer,            
              metrics=['accuracy'])


  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = epochs,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
history_adam=modelo_ejercicio3('relu','adam')
history_RMSprop=modelo_ejercicio3('relu','RMSprop')
# Out:
# Model: "sequential_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 128)               100480
#
#  dense_19 (Dense)            (None, 64)                8256
#
#  dense_20 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 6s 6ms/step - loss: 0.5331 - accuracy: 0.8139 - val_loss: 0.4203 - val_accuracy: 0.8470
# Epoch 2/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.3895 - accuracy: 0.8604 - val_loss: 0.3804 - val_accuracy: 0.8625
# Epoch 3/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3454 - accuracy: 0.8749 - val_loss: 0.3726 - val_accuracy: 0.8658
# Epoch 4/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.3211 - accuracy: 0.8825 - val_loss: 0.3471 - val_accuracy: 0.8742
# Epoch 5/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.3033 - accuracy: 0.8876 - val_loss: 0.3709 - val_accuracy: 0.8649
# Epoch 6/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2856 - accuracy: 0.8949 - val_loss: 0.3227 - val_accuracy: 0.8823
# Epoch 7/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.2742 - accuracy: 0.8979 - val_loss: 0.3223 - val_accuracy: 0.8847
# Epoch 8/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2663 - accuracy: 0.9008 - val_loss: 0.3344 - val_accuracy: 0.8777
# Epoch 9/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2520 - accuracy: 0.9058 - val_loss: 0.3562 - val_accuracy: 0.8744
# Epoch 10/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.2458 - accuracy: 0.9080 - val_loss: 0.3242 - val_accuracy: 0.8848
# Epoch 11/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2368 - accuracy: 0.9109 - val_loss: 0.3307 - val_accuracy: 0.8835
# Epoch 12/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2247 - accuracy: 0.9161 - val_loss: 0.3149 - val_accuracy: 0.8888
# Epoch 13/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.2162 - accuracy: 0.9193 - val_loss: 0.3288 - val_accuracy: 0.8878
# Epoch 14/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2126 - accuracy: 0.9200 - val_loss: 0.3189 - val_accuracy: 0.8916
# Epoch 15/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2038 - accuracy: 0.9239 - val_loss: 0.3349 - val_accuracy: 0.8914
# Epoch 16/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.1976 - accuracy: 0.9265 - val_loss: 0.3405 - val_accuracy: 0.8873
# Epoch 17/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1914 - accuracy: 0.9267 - val_loss: 0.3242 - val_accuracy: 0.8911
# Epoch 18/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.1873 - accuracy: 0.9293 - val_loss: 0.3249 - val_accuracy: 0.8938
# Epoch 19/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.1796 - accuracy: 0.9333 - val_loss: 0.3269 - val_accuracy: 0.8938
# Epoch 20/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1727 - accuracy: 0.9358 - val_loss: 0.3418 - val_accuracy: 0.8942
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_21 (Dense)            (None, 128)               100480
#
#  dense_22 (Dense)            (None, 64)                8256
#
#  dense_23 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.5498 - accuracy: 0.8060 - val_loss: 0.4343 - val_accuracy: 0.8462
# Epoch 2/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3911 - accuracy: 0.8577 - val_loss: 0.3796 - val_accuracy: 0.8627
# Epoch 3/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3520 - accuracy: 0.8729 - val_loss: 0.3409 - val_accuracy: 0.8791
# Epoch 4/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.3254 - accuracy: 0.8803 - val_loss: 0.3438 - val_accuracy: 0.8792
# Epoch 5/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.3085 - accuracy: 0.8855 - val_loss: 0.3406 - val_accuracy: 0.8799
# Epoch 6/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2938 - accuracy: 0.8915 - val_loss: 0.3454 - val_accuracy: 0.8804
# Epoch 7/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2802 - accuracy: 0.8959 - val_loss: 0.3570 - val_accuracy: 0.8807
# Epoch 8/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.2740 - accuracy: 0.8984 - val_loss: 0.3401 - val_accuracy: 0.8813
# Epoch 9/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2629 - accuracy: 0.9040 - val_loss: 0.3441 - val_accuracy: 0.8816
# Epoch 10/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2548 - accuracy: 0.9045 - val_loss: 0.3474 - val_accuracy: 0.8827
# Epoch 11/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.2491 - accuracy: 0.9067 - val_loss: 0.3811 - val_accuracy: 0.8741
# Epoch 12/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2419 - accuracy: 0.9091 - val_loss: 0.3428 - val_accuracy: 0.8867
# Epoch 13/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2358 - accuracy: 0.9124 - val_loss: 0.3401 - val_accuracy: 0.8882
# Epoch 14/20
# 750/750 [==============================] - 4s 6ms/step - loss: 0.2295 - accuracy: 0.9145 - val_loss: 0.3576 - val_accuracy: 0.8904
# Epoch 15/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2221 - accuracy: 0.9177 - val_loss: 0.3659 - val_accuracy: 0.8882
# Epoch 16/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2197 - accuracy: 0.9189 - val_loss: 0.4382 - val_accuracy: 0.8679
# Epoch 17/20
# 750/750 [==============================] - 5s 6ms/step - loss: 0.2155 - accuracy: 0.9193 - val_loss: 0.3899 - val_accuracy: 0.8845
# Epoch 18/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2113 - accuracy: 0.9221 - val_loss: 0.3665 - val_accuracy: 0.8881
# Epoch 19/20
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2081 - accuracy: 0.9233 - val_loss: 0.3937 - val_accuracy: 0.8837
# Epoch 20/20
# 750/750 [==============================] - 5s 7ms/step - loss: 0.2054 - accuracy: 0.9232 - val_loss: 0.3707 - val_accuracy: 0.8899

# %%
history_sgd= history_glorot
plot_compare_accs(history_adam, history_sgd, name1="history_adam",name2="history_sgd", title="Acurracy Adam vs SGD")
plot_compare_losses(history_adam, history_sgd, name1="history_adam",name2="history_sgd", title="Perdida Adam vs SGD")

# %% [markdown]
# #### Conclusión
#
# Estamos comparado Stochastic Gradient Descent, con un metodo adaptive learning rate. En este caso podemos apreciar que el optimiador ADAM se comporta mejor esto se debe a que utiliza una estrategia que los parámetros que se utilizan más a menudo tengan cambios más pequeños, por el contrario aquellos parámentros que se utilizan con menos actualizaciones de gradientes vean acelerada su learning reate. Cabe destacar que en las últimas epoch se aprecia el comienzo de Overfitting.

# %% [markdown]
# ###Experimento 5 - RSMprop vs SGD

# %%
plot_compare_accs(history_RMSprop, history_sgd, name1="history_RMSprop",name2="history_sgd", title="Acurracy RMSprop vs SGD")
plot_compare_losses(history_RMSprop, history_sgd, name1="history_RMSprop",name2="history_sgd", title="Perdida RMSprop vs SGD")

# %% [markdown]
# #### Conclusión
#
# En este caso nos estamo comparando SGD con RSMprop. Podemos apreciar que aunque en la parte de entrenamiento RSMprop se comporta mejor a partir la epoch 5 se produce Overfitting.
#
# ---

# %% [markdown]
# ## 4. Regularización y red final

# %% [markdown]
# **Ejercicio 4.1**: Entrenar una red final que sea capaz de obtener una accuracy en el validation set cercana al 90%. Para ello, combinar todo lo aprendido anteriormente y utilizar técnicas de regularización para evitar overfitting. Algunos de los elementos que pueden tenerse en cuenta son los siguientes.
#
# * Número de capas y neuronas por capa
# * Optimizadores y sus parámetros
# * Batch size
# * Unidades de activación
# * Uso de capas dropout, regularización L2, regularización L1...
# * Early stopping (se puede aplicar como un callback de Keras, o se puede ver un poco "a ojo" cuándo el modelo empieza a caer en overfitting y seleccionar el número de epochs necesarias)
# * Batch normalization
#
# Si los modelos entrenados anteriormente ya se acercaban al valor requerido de accuracy, probar distintas estrategias igualmente y comentar los resultados.
#
# Explicar brevemente la estrategia seguida y los modelos probados para obtener el modelo final, que debe verse entrenado en este Notebook. No es necesario guardar el entrenamiento de todos los modelos que se han probado, es suficiente con explicar cómo se ha llegado al modelo final.

# %% [markdown]
# ### Experimento 6 - Adicción de más capas + early stopping

# %% [markdown]
# Vamos a añadir más capas a nuestra red y añadirle la técnica de regularización Earty stopping

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

def modeloMasCapas():


  callbacks = [EarlyStopping(monitor='val_loss', patience=3)]

  model = Sequential()
  model.add(Dense(512,activation='relu', input_shape=(784,)))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    callbacks=callbacks,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
 history_mascapas=modeloMasCapas()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 512)               401920
#
#  dense_25 (Dense)            (None, 256)               131328
#
#  dense_26 (Dense)            (None, 256)               65792
#
#  dense_27 (Dense)            (None, 256)               65792
#
#  dense_28 (Dense)            (None, 256)               65792
#
#  dense_29 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 733,194
# Trainable params: 733,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 14s 18ms/step - loss: 0.5216 - accuracy: 0.8106 - val_loss: 0.4119 - val_accuracy: 0.8528
# Epoch 2/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.3854 - accuracy: 0.8600 - val_loss: 0.4062 - val_accuracy: 0.8492
# Epoch 3/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.3419 - accuracy: 0.8754 - val_loss: 0.3854 - val_accuracy: 0.8643
# Epoch 4/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.3204 - accuracy: 0.8827 - val_loss: 0.3578 - val_accuracy: 0.8698
# Epoch 5/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.3018 - accuracy: 0.8888 - val_loss: 0.3281 - val_accuracy: 0.8856
# Epoch 6/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.2873 - accuracy: 0.8941 - val_loss: 0.3474 - val_accuracy: 0.8802
# Epoch 7/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.2737 - accuracy: 0.8991 - val_loss: 0.3399 - val_accuracy: 0.8846
# Epoch 8/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.2623 - accuracy: 0.9014 - val_loss: 0.3201 - val_accuracy: 0.8882
# Epoch 9/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.2520 - accuracy: 0.9057 - val_loss: 0.3300 - val_accuracy: 0.8877
# Epoch 10/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.2430 - accuracy: 0.9090 - val_loss: 0.3462 - val_accuracy: 0.8810
# Epoch 11/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2336 - accuracy: 0.9120 - val_loss: 0.3342 - val_accuracy: 0.8850

# %%
plot_compare_accs(history_adam, history_mascapas, name1="history_adam",name2="history_mascapas", title="Acurracy Adam vs MasCapas")
plot_compare_losses(history_adam, history_mascapas, name1="history_adam",name2="history_mascapas", title="Perdida Adam vs MasCapas")

# %% [markdown]
# ###Conclusión
#  Las gráficas son muy parecidas debido a que son arquitecturas muy sencilla, nos quedaria la duda que pasaria si no aplicaremos early stopping, debido a que el accurracy de validación de la red más simple es mejor en las últimas epocas.

# %% [markdown]
# ###Experimento 7 - Adicción de más capas sin early stopping

# %% [markdown]
# Vamos a utilizar en este experimento la misma arquitectura del punto anterior pero sin early stopping.

# %%
def modeloMasCapasSinES():



  model = Sequential()
  model.add(Dense(512,activation='relu', input_shape=(784,)))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(256,activation='relu'))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
  history_mascapasinES=modeloMasCapasSinES()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_30 (Dense)            (None, 512)               401920
#
#  dense_31 (Dense)            (None, 256)               131328
#
#  dense_32 (Dense)            (None, 256)               65792
#
#  dense_33 (Dense)            (None, 256)               65792
#
#  dense_34 (Dense)            (None, 256)               65792
#
#  dense_35 (Dense)            (None, 10)                2570
#
# =================================================================
# Total params: 733,194
# Trainable params: 733,194
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 750/750 [==============================] - 14s 18ms/step - loss: 0.5182 - accuracy: 0.8121 - val_loss: 0.4229 - val_accuracy: 0.8468
# Epoch 2/20
# 750/750 [==============================] - 14s 18ms/step - loss: 0.3804 - accuracy: 0.8618 - val_loss: 0.3827 - val_accuracy: 0.8568
# Epoch 3/20
# 750/750 [==============================] - 18s 23ms/step - loss: 0.3431 - accuracy: 0.8746 - val_loss: 0.3524 - val_accuracy: 0.8741
# Epoch 4/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.3156 - accuracy: 0.8833 - val_loss: 0.3761 - val_accuracy: 0.8701
# Epoch 5/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.3022 - accuracy: 0.8882 - val_loss: 0.3369 - val_accuracy: 0.8796
# Epoch 6/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2865 - accuracy: 0.8936 - val_loss: 0.3519 - val_accuracy: 0.8810
# Epoch 7/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2679 - accuracy: 0.9006 - val_loss: 0.3421 - val_accuracy: 0.8810
# Epoch 8/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2632 - accuracy: 0.9031 - val_loss: 0.3232 - val_accuracy: 0.8853
# Epoch 9/20
# 750/750 [==============================] - 14s 18ms/step - loss: 0.2511 - accuracy: 0.9064 - val_loss: 0.3349 - val_accuracy: 0.8855
# Epoch 10/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.2392 - accuracy: 0.9117 - val_loss: 0.3199 - val_accuracy: 0.8888
# Epoch 11/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2309 - accuracy: 0.9136 - val_loss: 0.3204 - val_accuracy: 0.8923
# Epoch 12/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2256 - accuracy: 0.9158 - val_loss: 0.3232 - val_accuracy: 0.8939
# Epoch 13/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2173 - accuracy: 0.9192 - val_loss: 0.3206 - val_accuracy: 0.8870
# Epoch 14/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2087 - accuracy: 0.9225 - val_loss: 0.3168 - val_accuracy: 0.8903
# Epoch 15/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.2019 - accuracy: 0.9242 - val_loss: 0.3252 - val_accuracy: 0.8925
# Epoch 16/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1944 - accuracy: 0.9279 - val_loss: 0.3295 - val_accuracy: 0.8968
# Epoch 17/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.1927 - accuracy: 0.9283 - val_loss: 0.3184 - val_accuracy: 0.8943
# Epoch 18/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.1841 - accuracy: 0.9307 - val_loss: 0.3633 - val_accuracy: 0.8895
# Epoch 19/20
# 750/750 [==============================] - 13s 18ms/step - loss: 0.1793 - accuracy: 0.9322 - val_loss: 0.3271 - val_accuracy: 0.8970
# Epoch 20/20
# 750/750 [==============================] - 13s 17ms/step - loss: 0.1743 - accuracy: 0.9350 - val_loss: 0.3483 - val_accuracy: 0.8937

# %%
plot_compare_accs(history_adam, history_mascapasinES, name1="history_adam",name2="history_mascapasinES", title="Acurracy Adam vs MasCapasSINES")
plot_compare_losses(history_adam, history_mascapasinES, name1="history_adam",name2="history_mascapasinES", title="Perdida Adam vs MasCapasSINES")

# %% [markdown]
# #### Conclusión
# Las gráficas son muy parecidas a efectos didacticos vamos a seguir con la arquitectura con  menos capas y sin early stopping. Debido a que es más rápida de entrenar y tiene menos overfitting.

# %% [markdown]
# ###Experimento 8 - Aumento BatchSize

# %%
def modeloBatchSize():


  batch_size = 256
  model = Sequential()
  model.add(Dense(128,activation=activation, input_shape=(784,)))
  model.add(Dense(64,activation=activation))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
  history_batchsize=modeloBatchSize()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_36 (Dense)            (None, 128)               100480
#
#  dense_37 (Dense)            (None, 64)                8256
#
#  dense_38 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 3s 10ms/step - loss: 0.6490 - accuracy: 0.7759 - val_loss: 0.4904 - val_accuracy: 0.8304
# Epoch 2/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4256 - accuracy: 0.8505 - val_loss: 0.4082 - val_accuracy: 0.8541
# Epoch 3/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3847 - accuracy: 0.8645 - val_loss: 0.3758 - val_accuracy: 0.8690
# Epoch 4/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3578 - accuracy: 0.8736 - val_loss: 0.3770 - val_accuracy: 0.8630
# Epoch 5/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.3380 - accuracy: 0.8789 - val_loss: 0.3760 - val_accuracy: 0.8677
# Epoch 6/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3208 - accuracy: 0.8848 - val_loss: 0.3632 - val_accuracy: 0.8722
# Epoch 7/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3056 - accuracy: 0.8890 - val_loss: 0.3704 - val_accuracy: 0.8682
# Epoch 8/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2923 - accuracy: 0.8926 - val_loss: 0.3439 - val_accuracy: 0.8750
# Epoch 9/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2810 - accuracy: 0.8960 - val_loss: 0.3418 - val_accuracy: 0.8761
# Epoch 10/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2755 - accuracy: 0.8995 - val_loss: 0.3438 - val_accuracy: 0.8788
# Epoch 11/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2631 - accuracy: 0.9029 - val_loss: 0.3405 - val_accuracy: 0.8822
# Epoch 12/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2548 - accuracy: 0.9067 - val_loss: 0.3251 - val_accuracy: 0.8855
# Epoch 13/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2467 - accuracy: 0.9084 - val_loss: 0.3207 - val_accuracy: 0.8889
# Epoch 14/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2400 - accuracy: 0.9123 - val_loss: 0.3202 - val_accuracy: 0.8871
# Epoch 15/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2338 - accuracy: 0.9126 - val_loss: 0.3346 - val_accuracy: 0.8859
# Epoch 16/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2303 - accuracy: 0.9144 - val_loss: 0.3182 - val_accuracy: 0.8871
# Epoch 17/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2218 - accuracy: 0.9179 - val_loss: 0.3206 - val_accuracy: 0.8899
# Epoch 18/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2206 - accuracy: 0.9181 - val_loss: 0.3193 - val_accuracy: 0.8887
# Epoch 19/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2140 - accuracy: 0.9204 - val_loss: 0.3390 - val_accuracy: 0.8818
# Epoch 20/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2029 - accuracy: 0.9254 - val_loss: 0.3505 - val_accuracy: 0.8853

# %%
plot_compare_accs(history_adam, history_batchsize, name1="history_adam",name2="history_batchsize", title="Acurracy Adam vs Batchsize")
plot_compare_losses(history_adam, history_batchsize, name1="history_adam",name2="history_batchsize", title="Perdida Adam vs Batchsize")

# %% [markdown]
# Al aumentar el batch size optenemos mejores aproximaciones, vemos que la gráfica tiene menor overfitting y picos. A ser más uniforme vamos escoger este último para seguir con nuestros experimentos.

# %% [markdown]
# ### Experimento 9 - Aplicar BatchNormalization
#
# ---

# %%
def modeloBatchNormalization():


  batch_size = 256
  model = Sequential()
  model.add(Dense(128,activation=activation, input_shape=(784,)))
  BatchNormalization()
  model.add(Dense(64,activation=activation))
  BatchNormalization()
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
  history_batchnormalization=modeloBatchNormalization()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_39 (Dense)            (None, 128)               100480
#
#  dense_40 (Dense)            (None, 64)                8256
#
#  dense_41 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 3s 11ms/step - loss: 0.6486 - accuracy: 0.7806 - val_loss: 0.4754 - val_accuracy: 0.8295
# Epoch 2/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.4248 - accuracy: 0.8523 - val_loss: 0.4050 - val_accuracy: 0.8587
# Epoch 3/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.3836 - accuracy: 0.8655 - val_loss: 0.3752 - val_accuracy: 0.8685
# Epoch 4/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3548 - accuracy: 0.8741 - val_loss: 0.3804 - val_accuracy: 0.8641
# Epoch 5/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3318 - accuracy: 0.8801 - val_loss: 0.3770 - val_accuracy: 0.8659
# Epoch 6/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3175 - accuracy: 0.8855 - val_loss: 0.3358 - val_accuracy: 0.8793
# Epoch 7/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3018 - accuracy: 0.8898 - val_loss: 0.3373 - val_accuracy: 0.8802
# Epoch 8/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2878 - accuracy: 0.8946 - val_loss: 0.3297 - val_accuracy: 0.8798
# Epoch 9/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2742 - accuracy: 0.8998 - val_loss: 0.3350 - val_accuracy: 0.8794
# Epoch 10/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2677 - accuracy: 0.9014 - val_loss: 0.3311 - val_accuracy: 0.8807
# Epoch 11/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2591 - accuracy: 0.9042 - val_loss: 0.3142 - val_accuracy: 0.8882
# Epoch 12/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2560 - accuracy: 0.9052 - val_loss: 0.3215 - val_accuracy: 0.8842
# Epoch 13/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2464 - accuracy: 0.9102 - val_loss: 0.3199 - val_accuracy: 0.8869
# Epoch 14/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2383 - accuracy: 0.9118 - val_loss: 0.3170 - val_accuracy: 0.8886
# Epoch 15/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2312 - accuracy: 0.9150 - val_loss: 0.3104 - val_accuracy: 0.8908
# Epoch 16/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2253 - accuracy: 0.9168 - val_loss: 0.3149 - val_accuracy: 0.8886
# Epoch 17/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2197 - accuracy: 0.9179 - val_loss: 0.3119 - val_accuracy: 0.8906
# Epoch 18/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2146 - accuracy: 0.9207 - val_loss: 0.3146 - val_accuracy: 0.8908
# Epoch 19/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2084 - accuracy: 0.9231 - val_loss: 0.3187 - val_accuracy: 0.8883
# Epoch 20/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2053 - accuracy: 0.9244 - val_loss: 0.3157 - val_accuracy: 0.8912

# %%
plot_compare_accs(history_batchnormalization, history_batchsize, name1="history_batchnormalization",name2="history_batchsize", title="Acurracy batchnormalization vs Batchsize")
plot_compare_losses(history_batchnormalization, history_batchsize, name1="history_batchnormalization",name2="history_batchsize", title="Perdida batchnormalization vs Batchsize")

# %% [markdown]
# #### Conclusión:
# No apreciamos mejoria. Al ser una red muy pequeña la normalización no hace efecto debido a que la x que llega en cada capa es pequeña (wx + b), sólo tenemos una capa oculta.

# %% [markdown]
# ### Experimento 10 - Aplicar regularización L2
#
# *   Elemento de lista
# *   Elemento de lista

# %%
from keras.regularizers import l2
def modeloRegularizacionL2():


  batch_size = 256
  model = Sequential()
  model.add(Dense(128,activation='relu',kernel_regularizer=l2(0.01), input_shape=(784,)))
  model.add(Dense(64,activation='relu'))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
history_l2=modeloRegularizacionL2()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_42 (Dense)            (None, 128)               100480
#
#  dense_43 (Dense)            (None, 64)                8256
#
#  dense_44 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 4s 14ms/step - loss: 1.4503 - accuracy: 0.7725 - val_loss: 0.7581 - val_accuracy: 0.8297
# Epoch 2/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.6598 - accuracy: 0.8322 - val_loss: 0.5933 - val_accuracy: 0.8412
# Epoch 3/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5603 - accuracy: 0.8408 - val_loss: 0.5391 - val_accuracy: 0.8418
# Epoch 4/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.5300 - accuracy: 0.8425 - val_loss: 0.5208 - val_accuracy: 0.8421
# Epoch 5/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.5065 - accuracy: 0.8497 - val_loss: 0.5052 - val_accuracy: 0.8489
# Epoch 6/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4955 - accuracy: 0.8511 - val_loss: 0.5292 - val_accuracy: 0.8391
# Epoch 7/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.4810 - accuracy: 0.8533 - val_loss: 0.4850 - val_accuracy: 0.8533
# Epoch 8/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.4719 - accuracy: 0.8586 - val_loss: 0.4561 - val_accuracy: 0.8643
# Epoch 9/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4629 - accuracy: 0.8588 - val_loss: 0.4838 - val_accuracy: 0.8506
# Epoch 10/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4590 - accuracy: 0.8620 - val_loss: 0.4640 - val_accuracy: 0.8568
# Epoch 11/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4618 - accuracy: 0.8600 - val_loss: 0.4860 - val_accuracy: 0.8504
# Epoch 12/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4555 - accuracy: 0.8616 - val_loss: 0.4503 - val_accuracy: 0.8656
# Epoch 13/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4433 - accuracy: 0.8659 - val_loss: 0.5068 - val_accuracy: 0.8403
# Epoch 14/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4419 - accuracy: 0.8659 - val_loss: 0.4568 - val_accuracy: 0.8587
# Epoch 15/20
# 188/188 [==============================] - 3s 14ms/step - loss: 0.4411 - accuracy: 0.8660 - val_loss: 0.4452 - val_accuracy: 0.8658
# Epoch 16/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4385 - accuracy: 0.8660 - val_loss: 0.4555 - val_accuracy: 0.8638
# Epoch 17/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4301 - accuracy: 0.8705 - val_loss: 0.4536 - val_accuracy: 0.8633
# Epoch 18/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4294 - accuracy: 0.8694 - val_loss: 0.4659 - val_accuracy: 0.8552
# Epoch 19/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.4199 - accuracy: 0.8707 - val_loss: 0.4511 - val_accuracy: 0.8607
# Epoch 20/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4162 - accuracy: 0.8739 - val_loss: 0.4762 - val_accuracy: 0.8497

# %%
plot_compare_accs(history_l2, history_batchsize, name1="history_l2",name2="history_batchsize", title="Acurracy l2 vs Batchsize")
plot_compare_losses(history_l2, history_batchsize, name1="history_l2",name2="history_batchsize", title="Perdida l2 vs Batchsize")

# %% [markdown]
# #### Conclusión
# No soluciona el problema de overfitting y el desempeño es menor por lo que desechamos este experimento.

# %% [markdown]
# ### Experimento 11 - Aplicar regularización L1

# %%
from keras.regularizers import l1
def modeloRegularizacionL1():


  batch_size = 256
  model = Sequential()
  model.add(Dense(128,activation='relu',kernel_regularizer=l1(0.01), input_shape=(784,)))
  model.add(Dense(64,activation='relu'))
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
history_l1=modeloRegularizacionL1()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_45 (Dense)            (None, 128)               100480
#
#  dense_46 (Dense)            (None, 64)                8256
#
#  dense_47 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 4s 14ms/step - loss: 8.0241 - accuracy: 0.6661 - val_loss: 1.3395 - val_accuracy: 0.7473
# Epoch 2/20
# 188/188 [==============================] - 2s 9ms/step - loss: 1.2207 - accuracy: 0.7501 - val_loss: 1.1612 - val_accuracy: 0.7541
# Epoch 3/20
# 188/188 [==============================] - 2s 10ms/step - loss: 1.0766 - accuracy: 0.7720 - val_loss: 1.0428 - val_accuracy: 0.7733
# Epoch 4/20
# 188/188 [==============================] - 2s 9ms/step - loss: 1.0123 - accuracy: 0.7793 - val_loss: 1.0248 - val_accuracy: 0.7750
# Epoch 5/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.9766 - accuracy: 0.7861 - val_loss: 0.9771 - val_accuracy: 0.7751
# Epoch 6/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.9504 - accuracy: 0.7898 - val_loss: 0.9665 - val_accuracy: 0.7843
# Epoch 7/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.9190 - accuracy: 0.7954 - val_loss: 0.9187 - val_accuracy: 0.7971
# Epoch 8/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.9028 - accuracy: 0.7999 - val_loss: 0.8941 - val_accuracy: 0.7981
# Epoch 9/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.9018 - accuracy: 0.7970 - val_loss: 0.8877 - val_accuracy: 0.8052
# Epoch 10/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8891 - accuracy: 0.7997 - val_loss: 0.9158 - val_accuracy: 0.7908
# Epoch 11/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.8606 - accuracy: 0.8047 - val_loss: 0.8481 - val_accuracy: 0.8119
# Epoch 12/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8686 - accuracy: 0.8017 - val_loss: 0.9395 - val_accuracy: 0.7830
# Epoch 13/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8552 - accuracy: 0.8043 - val_loss: 0.8440 - val_accuracy: 0.8120
# Epoch 14/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.8544 - accuracy: 0.8061 - val_loss: 0.8396 - val_accuracy: 0.8100
# Epoch 15/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.8447 - accuracy: 0.8068 - val_loss: 0.8280 - val_accuracy: 0.8105
# Epoch 16/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.8435 - accuracy: 0.8080 - val_loss: 0.8405 - val_accuracy: 0.8142
# Epoch 17/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8382 - accuracy: 0.8097 - val_loss: 0.8346 - val_accuracy: 0.8138
# Epoch 18/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8287 - accuracy: 0.8119 - val_loss: 0.8283 - val_accuracy: 0.8142
# Epoch 19/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.8242 - accuracy: 0.8117 - val_loss: 0.8472 - val_accuracy: 0.8015
# Epoch 20/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.8203 - accuracy: 0.8138 - val_loss: 0.8988 - val_accuracy: 0.7912

# %%
plot_compare_accs(history_l1, history_batchsize, name1="history_l1",name2="history_batchsize", title="Acurracy l1 vs Batchsize")
plot_compare_losses(history_l1, history_batchsize, name1="history_l1",name2="history_batchsize", title="Perdida l1 vs Batchsize")

# %% [markdown]
# #### Conclusión
# No soluciona el problema de overfitting y el desempeño es menor por lo que desechamos este experimento. Llama la atención el salto en las primeras epocas en la funcion de perdida. Recordar que esta regularación tiende a que los parámetros se dispersen muchos se quedaban a "0" o cercanos. Esto en la inialización de una red neuronal es un factor en contra como hemos analizado en el experimento 3.

# %% [markdown]
# ### Experimento 12 - Aplicar Dropout 0.2

# %%
def modeloDropOut():


  batch_size = 256
  model = Sequential()
  model.add(Dense(128,activation='relu', input_shape=(784,)))
  Dropout(0.2)
  model.add(Dense(64,activation='relu'))
  Dropout(0.2)
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
history_dropout= modeloDropOut()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_48 (Dense)            (None, 128)               100480
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  dense_50 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 3s 10ms/step - loss: 0.6443 - accuracy: 0.7819 - val_loss: 0.4562 - val_accuracy: 0.8407
# Epoch 2/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4267 - accuracy: 0.8508 - val_loss: 0.4036 - val_accuracy: 0.8589
# Epoch 3/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3839 - accuracy: 0.8639 - val_loss: 0.3851 - val_accuracy: 0.8631
# Epoch 4/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3572 - accuracy: 0.8734 - val_loss: 0.3655 - val_accuracy: 0.8697
# Epoch 5/20
# 188/188 [==============================] - 3s 14ms/step - loss: 0.3302 - accuracy: 0.8823 - val_loss: 0.3456 - val_accuracy: 0.8777
# Epoch 6/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3185 - accuracy: 0.8854 - val_loss: 0.3510 - val_accuracy: 0.8730
# Epoch 7/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2991 - accuracy: 0.8910 - val_loss: 0.3396 - val_accuracy: 0.8768
# Epoch 8/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2933 - accuracy: 0.8926 - val_loss: 0.3288 - val_accuracy: 0.8813
# Epoch 9/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2794 - accuracy: 0.8986 - val_loss: 0.3240 - val_accuracy: 0.8822
# Epoch 10/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2743 - accuracy: 0.8998 - val_loss: 0.3188 - val_accuracy: 0.8852
# Epoch 11/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2617 - accuracy: 0.9046 - val_loss: 0.3239 - val_accuracy: 0.8842
# Epoch 12/20
# 188/188 [==============================] - 3s 13ms/step - loss: 0.2533 - accuracy: 0.9066 - val_loss: 0.3313 - val_accuracy: 0.8856
# Epoch 13/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2495 - accuracy: 0.9088 - val_loss: 0.3243 - val_accuracy: 0.8851
# Epoch 14/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2393 - accuracy: 0.9132 - val_loss: 0.3166 - val_accuracy: 0.8878
# Epoch 15/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2344 - accuracy: 0.9145 - val_loss: 0.3533 - val_accuracy: 0.8764
# Epoch 16/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2297 - accuracy: 0.9164 - val_loss: 0.3134 - val_accuracy: 0.8900
# Epoch 17/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2170 - accuracy: 0.9201 - val_loss: 0.3275 - val_accuracy: 0.8851
# Epoch 18/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2153 - accuracy: 0.9208 - val_loss: 0.3149 - val_accuracy: 0.8938
# Epoch 19/20
# 188/188 [==============================] - 3s 14ms/step - loss: 0.2121 - accuracy: 0.9220 - val_loss: 0.3312 - val_accuracy: 0.8867
# Epoch 20/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.2058 - accuracy: 0.9238 - val_loss: 0.3211 - val_accuracy: 0.8870

# %%
plot_compare_accs(history_dropout, history_batchsize, name1="history_dropout",name2="history_batchsize", title="Acurracy dropout vs Batchsize")
plot_compare_losses(history_dropout, history_batchsize, name1="history_dropout",name2="history_batchsize", title="Perdida dropout vs Batchsize")

# %% [markdown]
# Pese a tener menor desempeño la vamos a escoger debido a que así nuestra red no aprende sino va a generalizar.

# %% [markdown]
# ###Experimento 13 - Aplicar Dropout 0.5

# %%
def modeloDropOut5():


  batch_size = 256
  model = Sequential()
  model.add(Dense(128,activation='relu', input_shape=(784,)))
  Dropout(0.5)
  model.add(Dense(64,activation='relu'))
  Dropout(0.5)
  model.add(Dense(num_clases,activation='softmax'))

  model.summary()


  model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

  history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))

  return history

# %%
history_dropout5= modeloDropOut5()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_51 (Dense)            (None, 128)               100480
#
#  dense_52 (Dense)            (None, 64)                8256
#
#  dense_53 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 3s 11ms/step - loss: 0.6333 - accuracy: 0.7839 - val_loss: 0.4485 - val_accuracy: 0.8418
# Epoch 2/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.4254 - accuracy: 0.8515 - val_loss: 0.4024 - val_accuracy: 0.8583
# Epoch 3/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.3819 - accuracy: 0.8647 - val_loss: 0.4006 - val_accuracy: 0.8604
# Epoch 4/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.3554 - accuracy: 0.8734 - val_loss: 0.3864 - val_accuracy: 0.8572
# Epoch 5/20
# 188/188 [==============================] - 3s 14ms/step - loss: 0.3352 - accuracy: 0.8800 - val_loss: 0.3691 - val_accuracy: 0.8661
# Epoch 6/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3152 - accuracy: 0.8856 - val_loss: 0.3404 - val_accuracy: 0.8776
# Epoch 7/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3048 - accuracy: 0.8891 - val_loss: 0.3699 - val_accuracy: 0.8685
# Epoch 8/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2938 - accuracy: 0.8923 - val_loss: 0.3407 - val_accuracy: 0.8760
# Epoch 9/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2810 - accuracy: 0.8970 - val_loss: 0.3385 - val_accuracy: 0.8778
# Epoch 10/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2704 - accuracy: 0.9010 - val_loss: 0.3417 - val_accuracy: 0.8783
# Epoch 11/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.2615 - accuracy: 0.9051 - val_loss: 0.3330 - val_accuracy: 0.8840
# Epoch 12/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2543 - accuracy: 0.9064 - val_loss: 0.3400 - val_accuracy: 0.8787
# Epoch 13/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2489 - accuracy: 0.9097 - val_loss: 0.3289 - val_accuracy: 0.8834
# Epoch 14/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2357 - accuracy: 0.9132 - val_loss: 0.3242 - val_accuracy: 0.8873
# Epoch 15/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2316 - accuracy: 0.9146 - val_loss: 0.3221 - val_accuracy: 0.8863
# Epoch 16/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2227 - accuracy: 0.9179 - val_loss: 0.3310 - val_accuracy: 0.8848
# Epoch 17/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2177 - accuracy: 0.9202 - val_loss: 0.3200 - val_accuracy: 0.8903
# Epoch 18/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2114 - accuracy: 0.9229 - val_loss: 0.3194 - val_accuracy: 0.8887
# Epoch 19/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2120 - accuracy: 0.9215 - val_loss: 0.3218 - val_accuracy: 0.8901
# Epoch 20/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.1987 - accuracy: 0.9263 - val_loss: 0.3342 - val_accuracy: 0.8866

# %%
plot_compare_accs(history_dropout, history_dropout5, name1="history_dropout2",name2="history_dropout5", title="Acurracy 0.2 vs 0.5")
plot_compare_losses(history_dropout, history_dropout5, name1="history_dropou2",name2="history_dropout5", title="Perdida 0.2 vs 0.5")

# %% [markdown]
# #### Conclusión
#  Generaliza mejor para este experimento nuestro modelo con 0.5, esta actuando como un ensemble de modelos, donde cambia en cada bacth, consiguiento entrenar un gran número de redes neuronales ligeramente distintas.

# %% [markdown]
# ### Evaluación del modelo en datos de test

# %% [markdown]
# Una vez elegido el que creemos que es nuestro mejor modelo a partir de la estimación que hemos visto en los datos de validación, es hora de utilizar los datos de test para ver cómo se comporta nuestro modelo ante nuevos datos. Si hemos hecho bien las cosas, este número debería ser parecido al valor de nuestra estimación vista en los datos de validación.
#
# **Pregunta 4.2**. Utilizando nuestro mejor modelo, obtener la accuracy resultante en el dataset de test. Comentar este resultado.

# %% [markdown]
# ### Experimento 14, Análisis Accuracy
#
# *   Elemento de lista
# *   Elemento de lista

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint

batch_size = 256
model = Sequential()
model.add(Dense(128,activation='relu', input_shape=(784,)))
Dropout(0.5)
model.add(Dense(64,activation='relu'))
Dropout(0.5)
model.add(Dense(num_clases,activation='softmax'))

model.summary()


model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

history = model.fit(x_train, y_train,
                    batch_size = batch_size,
                    epochs = 20,
                    verbose=1,
                    validation_data=(x_val, y_val))
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_54 (Dense)            (None, 128)               100480
#
#  dense_55 (Dense)            (None, 64)                8256
#
#  dense_56 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 109,386
# Trainable params: 109,386
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 188/188 [==============================] - 3s 10ms/step - loss: 0.6451 - accuracy: 0.7834 - val_loss: 0.4836 - val_accuracy: 0.8338
# Epoch 2/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.4280 - accuracy: 0.8512 - val_loss: 0.4115 - val_accuracy: 0.8569
# Epoch 3/20
# 188/188 [==============================] - 3s 13ms/step - loss: 0.3834 - accuracy: 0.8634 - val_loss: 0.3860 - val_accuracy: 0.8627
# Epoch 4/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3519 - accuracy: 0.8747 - val_loss: 0.3988 - val_accuracy: 0.8547
# Epoch 5/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3347 - accuracy: 0.8790 - val_loss: 0.3461 - val_accuracy: 0.8752
# Epoch 6/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.3158 - accuracy: 0.8860 - val_loss: 0.3521 - val_accuracy: 0.8764
# Epoch 7/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.3046 - accuracy: 0.8889 - val_loss: 0.3745 - val_accuracy: 0.8658
# Epoch 8/20
# 188/188 [==============================] - 2s 8ms/step - loss: 0.2930 - accuracy: 0.8925 - val_loss: 0.3197 - val_accuracy: 0.8863
# Epoch 9/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2803 - accuracy: 0.8973 - val_loss: 0.3186 - val_accuracy: 0.8856
# Epoch 10/20
# 188/188 [==============================] - 2s 12ms/step - loss: 0.2713 - accuracy: 0.9016 - val_loss: 0.3192 - val_accuracy: 0.8851
# Epoch 11/20
# 188/188 [==============================] - 2s 11ms/step - loss: 0.2626 - accuracy: 0.9035 - val_loss: 0.3404 - val_accuracy: 0.8792
# Epoch 12/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2562 - accuracy: 0.9058 - val_loss: 0.3216 - val_accuracy: 0.8854
# Epoch 13/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2498 - accuracy: 0.9083 - val_loss: 0.3244 - val_accuracy: 0.8828
# Epoch 14/20
# 188/188 [==============================] - 2s 13ms/step - loss: 0.2486 - accuracy: 0.9074 - val_loss: 0.3082 - val_accuracy: 0.8918
# Epoch 15/20
# 188/188 [==============================] - 3s 15ms/step - loss: 0.2355 - accuracy: 0.9130 - val_loss: 0.3177 - val_accuracy: 0.8894
# Epoch 16/20
# 188/188 [==============================] - 3s 16ms/step - loss: 0.2325 - accuracy: 0.9149 - val_loss: 0.3183 - val_accuracy: 0.8907
# Epoch 17/20
# 188/188 [==============================] - 2s 10ms/step - loss: 0.2226 - accuracy: 0.9181 - val_loss: 0.3076 - val_accuracy: 0.8882
# Epoch 18/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2183 - accuracy: 0.9195 - val_loss: 0.3204 - val_accuracy: 0.8863
# Epoch 19/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2125 - accuracy: 0.9227 - val_loss: 0.3249 - val_accuracy: 0.8837
# Epoch 20/20
# 188/188 [==============================] - 2s 9ms/step - loss: 0.2095 - accuracy: 0.9229 - val_loss: 0.3165 - val_accuracy: 0.8886

# %%
predictions = model.predict(x_test)
print(predictions)
score = model.evaluate(x_test, y_test,verbose=1)
print(score)
# Out:
# 313/313 [==============================] - 1s 2ms/step
# [[5.2550060e-08 8.0686219e-10 6.8116806e-06 ... 1.9243844e-03
#   1.6328298e-07 9.9728745e-01]
#  [1.6189286e-05 1.2921834e-12 9.9816430e-01 ... 6.1184205e-14
#   4.2085060e-09 8.0460541e-11]
#  [2.3553861e-07 9.9999970e-01 1.4319024e-09 ... 9.7097218e-16
#   1.8820907e-11 1.0862988e-12]
#  ...
#  [3.1111721e-04 5.5038307e-10 3.3841043e-05 ... 7.5006259e-09
#   9.9951881e-01 2.8314884e-09]
#  [2.2929744e-06 9.9997979e-01 1.2711175e-06 ... 3.6746515e-13
#   1.3402591e-07 4.4971453e-09]
#  [1.3402463e-06 1.9524425e-07 2.5726729e-06 ... 1.9624477e-04
#   1.1299344e-05 2.0585917e-06]]
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3533 - accuracy: 0.8781
# [0.35334378480911255, 0.8780999779701233]

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test.argmax(axis=1),
                            predictions.argmax(axis=1),
                            target_names=['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt',
                                          'Sneaker', 'Bag', 'Ankle boot']))
# Out:
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.88      0.76      0.81      1000
#      Trouser       0.99      0.97      0.98      1000
#     Pullover       0.84      0.70      0.76      1000
#        Dress       0.87      0.90      0.88      1000
#         Coat       0.78      0.83      0.80      1000
#       Sandal       0.97      0.96      0.97      1000
#        Shirt       0.63      0.78      0.70      1000
#      Sneaker       0.96      0.95      0.95      1000
#          Bag       0.99      0.96      0.97      1000
#   Ankle boot       0.95      0.97      0.96      1000
#
#     accuracy                           0.88     10000
#    macro avg       0.88      0.88      0.88     10000
# weighted avg       0.88      0.88      0.88     10000

# %% [markdown]
# El resultado es muy bueno ya que los datos de validación son muy parecidos a los de predicición. Por ejemplo el acurracy de validación fue 0.8898 mientras que en test fue de 0.8780. Por lado también se puede apreciar que donde ha habido más problemas es en la clase Shirt.
