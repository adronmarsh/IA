# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Ejercicio 1
#
# ![image.png](attachment:image.png)
#
# W = (32 - 6 + 2 * 2) / 1 + 1 = 56 / 2 = 28
#
# H = (32 - 6 + 2 * 2) / 1 + 1 = 56 / 2 = 28
#
# D = 10
#
# ---
# Volumen de salida: 28 x 28 x 10
#
# Número de parámetros: (6 x 6 x 3 + 1) * 10 = 1090
#
# ---

# %% [markdown]
# ### Ejercicio 2
#
# ![image.png](attachment:image.png)
#
# W = (32 - 6 + 2 * 2) / 2 + 1 = 16
#
# H = (32 - 6 + 2 * 2) / 2 + 1 = 16
#
# D = 10
#
# ---
# Volumen de salida: 16 x 16 x 10
#
# Número de parámetros: (6 x 6 x 3 + 1) * 10 = 1090
#
# ---

# %% [markdown]
# ### Ejercicio 3
#
# ![image.png](attachment:image.png)
#
# W = (32 - 6 + 2 * 2) / 3 + 1 = 11
#
# H = (32 - 6 + 2 * 2) / 3 + 1 = 11
#
# D = 10
#
# ---
# Volumen de salida: 11 x 11 x 10
#
# Número de parámetros: (6 x 6 x 3 + 1) * 10 = 1090
#
# ---

# %% [markdown]
# ### Ejercicio 4
#
# ![image.png](attachment:image.png)
#
# W = (32 - 6 + 2 * 2) / 4 + 1 = 8.5
#
# H = (32 - 6 + 2 * 2) / 4 + 1 = 8.5
#
# D = 10
#
# ---
# Volumen de salida: No se puede aplicar ya que no puede ser decimal
#
# Número de parámetros: (6 x 6 x 3 + 1) * 10 = 1090
#
# ---

# %% [markdown]
# ### Ejercicio 5
#
# ![image.png](attachment:image.png)
#
# W = (32 - 5 + 2 * 2) / 2 + 1 = 16.5
#
# H = (32 - 5 + 2 * 2) / 2 + 1 = 16.5
#
# D = 10
#
# ---
# Volumen de salida: No se puede aplicar ya que no puede ser decimal
#
# Número de parámetros: (5 x 5 x 3 + 1) * 10 = 760
#
# ---
