# %%
from confluent_kafka import Consumer, KafkaError, KafkaException
import sys

conf = {
    'bootstrap.servers': 'localhost:9092',
    'group.id': 'foo'
}

consumer = Consumer(conf)

running = True

topics = ["ejercicio2"]

def basic_consume_loop(consumer, topics):
    try:
        consumer.subscribe(topics)

        while running:
            msg = consumer.poll(timeout=1.0)
            if msg is None:
                continue

            if msg.error():
                if msg.error().code() == KafkaError._PARTITION_EOF:
                    # End of partition event
                    sys.stderr.write('%% %s [%d] reached end at offset %d\n' %
                                     (msg.topic(), msg.partition(), msg.offset()))
                else:
                    raise KafkaException(msg.error())
            else:
                print(msg)
                print('Mensaje Recibido: {}'.format(msg.value().decode('utf-8')))
    finally:
        # Close down consumer to commit final offsets.
        consumer.close()

def shutdown():
    global running
    running = False

basic_consume_loop(consumer, topics)
# Out:
# <cimpl.Message object at 0x7fe3e4232240>
# Mensaje Recibido: ('contenido del topic:', 0)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 1)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 2)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 3)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 4)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 5)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 6)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 7)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 8)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 9)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 10)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 11)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 12)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 13)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 14)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 15)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 16)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 17)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 18)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 19)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 20)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 21)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 22)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 23)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 24)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 25)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 26)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 27)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 28)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 29)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 30)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 31)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 32)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 33)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 34)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 35)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 36)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 37)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 38)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 39)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 40)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 41)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 42)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 43)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 44)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 45)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 46)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 47)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 48)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 49)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 50)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 51)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 52)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 53)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 54)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 55)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 56)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 57)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 58)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 59)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 60)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 61)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 62)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 63)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 64)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 65)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 66)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 67)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 68)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 69)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 70)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 71)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 72)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 73)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 74)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 75)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 76)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 77)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 78)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 79)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 80)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 81)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 82)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 83)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 84)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 85)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 86)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 87)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 88)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 89)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 90)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 91)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 92)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 93)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 94)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 95)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 96)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 97)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 98)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 99)
# <cimpl.Message object at 0x7fe3e4230340>
# Mensaje Recibido: ('contenido del topic:', 0)
# <cimpl.Message object at 0x7fe3e4232240>
# Mensaje Recibido: ('contenido del topic:', 1)
# %6|1701368934.825|FAIL|rdkafka#consumer-5| [thrd:A208-100:9092/0]: A208-100:9092/0: Disconnected (after 2986959ms in state UP)
# %3|1701368934.825|FAIL|rdkafka#consumer-5| [thrd:A208-100:9092/0]: A208-100:9092/0: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %6|1701368934.827|FAIL|rdkafka#consumer-5| [thrd:GroupCoordinator]: GroupCoordinator: A208-100:9092: Disconnected (after 2986966ms in state UP)
# %3|1701368934.827|FAIL|rdkafka#consumer-5| [thrd:GroupCoordinator]: GroupCoordinator: A208-100:9092: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1701368934.827|FAIL|rdkafka#consumer-5| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT)
# %3|1701368934.891|FAIL|rdkafka#consumer-5| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1701368935.001|FAIL|rdkafka#consumer-5| [thrd:GroupCoordinator]: GroupCoordinator: A208-100:9092: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1701368935.058|FAIL|rdkafka#consumer-5| [thrd:A208-100:9092/0]: A208-100:9092/0: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 1 identical error(s) suppressed)
# %3|1701368964.892|FAIL|rdkafka#consumer-5| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 66 identical error(s) suppressed)
# %3|1701368967.243|FAIL|rdkafka#consumer-5| [thrd:A208-100:9092/0]: A208-100:9092/0: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 5 identical error(s) suppressed)
# %3|1701368969.942|FAIL|rdkafka#consumer-5| [thrd:GroupCoordinator]: GroupCoordinator: A208-100:9092: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 5 identical error(s) suppressed)
# %4|1701368978.428|SESSTMOUT|rdkafka#consumer-5| [thrd:main]: Consumer group session timed out (in join-state steady) after 45000 ms without a successful response from the group coordinator (broker 0, last error was Success): revoking assignment and rejoining group
# %3|1701368996.892|FAIL|rdkafka#consumer-5| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 53 identical error(s) suppressed)
# %3|1701368997.428|FAIL|rdkafka#consumer-5| [thrd:A208-100:9092/0]: A208-100:9092/0: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 17 identical error(s) suppressed)
# %3|1701369009.589|FAIL|rdkafka#consumer-5| [thrd:GroupCoordinator]: GroupCoordinator: A208-100:9092: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
# %3|1701369026.892|FAIL|rdkafka#consumer-5| [thrd:localhost:9092/bootstrap]: localhost:9092/bootstrap: Connect to ipv4#127.0.0.1:9092 failed: Connection refused (after 0ms in state CONNECT, 30 identical error(s) suppressed)
# %3|1701369027.880|FAIL|rdkafka#consumer-5| [thrd:A208-100:9092/0]: A208-100:9092/0: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 33 identical error(s) suppressed)
# %3|1701369049.054|FAIL|rdkafka#consumer-5| [thrd:GroupCoordinator]: GroupCoordinator: A208-100:9092: Connect to ipv4#127.0.1.1:9092 failed: Connection refused (after 0ms in state CONNECT, 4 identical error(s) suppressed)
