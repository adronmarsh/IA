# %%
import tensorflow as tf
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os


plt.rcParams['figure.figsize'] = (8,6)
plt.rcParams['axes.grid'] = False
# Out:
# WARNING:tensorflow:From c:\Users\Adron\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
zip_path = tf.keras.utils.get_file(
    origin='https://storage.googleapis.com/tensorflow/tf-keras-datasets/jena_climate_2009_2016.csv.zip',
    fname='jena_climate_2009_2016.csv.zip',
    extract=True
)
csv_path, _ = os.path.splitext(zip_path)
df = pd.read_csv(csv_path)
df
# Out:
# ...
# 13568290/13568290 [==============================] - 2s 0us/step
#                   Date Time  p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  \
# 0       01.01.2009 00:10:00    996.52     -8.02    265.40        -8.90
# 1       01.01.2009 00:20:00    996.57     -8.41    265.01        -9.28
# 2       01.01.2009 00:30:00    996.53     -8.51    264.91        -9.31
# 3       01.01.2009 00:40:00    996.51     -8.31    265.12        -9.07
# 4       01.01.2009 00:50:00    996.51     -8.27    265.15        -9.04
# ...                     ...       ...       ...       ...          ...
# 420546  31.12.2016 23:20:00   1000.07     -4.05    269.10        -8.13
# 420547  31.12.2016 23:30:00    999.93     -3.35    269.81        -8.06
# 420548  31.12.2016 23:40:00    999.82     -3.16    270.01        -8.21
# 420549  31.12.2016 23:50:00    999.81     -4.23    268.94        -8.53
# 420550  01.01.2017 00:00:00    999.82     -4.82    268.36        -8.42
#
# ...

# %%
df = df[5::6]

# %%
date_time = pd.to_datetime(df.pop('Date Time'), format='%d.%m.%Y %H:%M:%S')

columnas = ['T (degC)', 'p (mbar)', 'rho (g/m**3)']
df_representar = df[columnas]
df_representar.index = date_time
_ = df_representar.plot(subplots=True)

# %%
df_mes = df[columnas][:480]
df_mes.index = date_time[:480]
_ = df_mes.plot(subplots=True)

# %%
df.describe().transpose()
# Out:
#                    count         mean        std      min      25%      50%  \
# p (mbar)         70091.0   989.212842   8.358886   913.60   984.20   989.57
# T (degC)         70091.0     9.450482   8.423384   -22.76     3.35     9.41
# Tpot (K)         70091.0   283.493086   8.504424   250.85   277.44   283.46
# Tdew (degC)      70091.0     4.956471   6.730081   -24.80     0.24     5.21
# rh (%)           70091.0    76.009788  16.474920    13.88    65.21    79.30
# VPmax (mbar)     70091.0    13.576576   7.739883     0.97     7.77    11.82
# VPact (mbar)     70091.0     9.533968   4.183658     0.81     6.22     8.86
# VPdef (mbar)     70091.0     4.042536   4.898549     0.00     0.87     2.19
# sh (g/kg)        70091.0     6.022560   2.655812     0.51     3.92     5.59
# H2OC (mmol/mol)  70091.0     9.640437   4.234862     0.81     6.29     8.96
# rho (g/m**3)     70091.0  1216.061232  39.974263  1059.45  1187.47  1213.80
# ...

# %% [markdown]
# Se han detectado unos valores anómalos por lo que vamos a modificarlos. La velocidad mínima y máxima del viento no puede ser negativa

# %%
wv = df['wv (m/s)']
bad_wv = wv == -9999.0
wv[bad_wv] = 0.0

max_wv = df['max. wv (m/s)']
bad_max_wv = max_wv == -9999.0
max_wv[bad_max_wv] = 0.0
# Out:
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\2390606322.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wv[bad_wv] = 0.0
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\2390606322.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   max_wv[bad_max_wv] = 0.0

# %% [markdown]
# También hay que darle a entender al modelo que si hablamos de dirección del viento 0º es lo mismo que 360º y que la distancia entre 1º y 359º es menor que 1º y 4º
#
# ![image.png](attachment:image.png)

# %%
wd_rad = df.pop('wd (deg)')*np.pi /180
df['Wx'] = wv*np.cos(wd_rad)
df['Wy'] = wv*np.sin(wd_rad)

max_wv = df.pop('max. wv (m/s)')
df['max Wx'] = max_wv*np.cos(wd_rad)
df['max Wy'] = max_wv*np.sin(wd_rad)
# Out:
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\913554603.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wx'] = wv*np.cos(wd_rad)
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\913554603.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Wy'] = wv*np.sin(wd_rad)
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\913554603.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
df.describe().transpose()
# Out:
#                    count         mean        std          min          25%  \
# p (mbar)         70091.0   989.212842   8.358886   913.600000   984.200000
# T (degC)         70091.0     9.450482   8.423384   -22.760000     3.350000
# Tpot (K)         70091.0   283.493086   8.504424   250.850000   277.440000
# Tdew (degC)      70091.0     4.956471   6.730081   -24.800000     0.240000
# rh (%)           70091.0    76.009788  16.474920    13.880000    65.210000
# VPmax (mbar)     70091.0    13.576576   7.739883     0.970000     7.770000
# VPact (mbar)     70091.0     9.533968   4.183658     0.810000     6.220000
# VPdef (mbar)     70091.0     4.042536   4.898549     0.000000     0.870000
# sh (g/kg)        70091.0     6.022560   2.655812     0.510000     3.920000
# H2OC (mmol/mol)  70091.0     9.640437   4.234862     0.810000     6.290000
# rho (g/m**3)     70091.0  1216.061232  39.974263  1059.450000  1187.470000
# ...

# %%
timestamp_s = date_time.map(pd.Timestamp.timestamp)

# %%
day = 24*60*60
year = 365.2425*day

df['day sin'] = np.sin(timestamp_s * (2*np.pi / day))
df['day cos'] =  np.cos(timestamp_s * (2*np.pi / day))
df['year sin'] = np.sin(timestamp_s * (2*np.pi / year))
df['year cos'] =  np.cos(timestamp_s * (2*np.pi / year))
# Out:
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\1595307756.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day sin'] = np.sin(timestamp_s * (2*np.pi / day))
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\1595307756.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['day cos'] =  np.cos(timestamp_s * (2*np.pi / day))
# C:\Users\Adron\AppData\Local\Temp\ipykernel_3176\1595307756.py:6: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#         p (mbar)  T (degC)  Tpot (K)  Tdew (degC)  rh (%)  VPmax (mbar)  \
# 5         996.50     -8.05    265.38        -8.78   94.40          3.33
# 11        996.62     -8.88    264.54        -9.77   93.20          3.12
# 17        996.84     -8.81    264.59        -9.66   93.50          3.13
# 23        996.99     -9.05    264.34       -10.02   92.60          3.07
# 29        997.46     -9.63    263.72       -10.65   92.20          2.94
# ...          ...       ...       ...          ...     ...           ...
# 420521   1002.18     -0.98    272.01        -5.36   72.00          5.69
# 420527   1001.40     -1.40    271.66        -6.84   66.29          5.51
# 420533   1001.19     -2.75    270.32        -6.90   72.90          4.99
# 420539   1000.65     -2.89    270.22        -7.15   72.30          4.93
# 420545   1000.11     -3.93    269.23        -8.09   72.60          4.56
#
#         VPact (mbar)  VPdef (mbar)  sh (g/kg)  H2OC (mmol/mol)  rho (g/m**3)  \
# ...
